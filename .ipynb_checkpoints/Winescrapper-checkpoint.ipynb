# %% [markdown]
# # Projeto Wine Scrapper
#
# > Um sistema para extração de dados e análise em sites de comércio e avaliação de vinhos
#
# ***

# %% [markdown]
# ## Parte 1 - Web scrapper do site da Wine.com.br
#
# ### 1.1. Testes com páginas individuais

# %%
import requests
page = requests.get("https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p1.html")

from bs4 import BeautifulSoup as bs

soup = bs(page.content, 'html.parser')


product = soup.find('article', class_='ProductDisplay')

ProductName = product.find('div', class_='ProductDisplay-name')
product_name_a = ProductName.find('a')

print(product_name_a['title'])
print("https://wine.com.br" + product_name_a['href'])

country = product.find(class_="Country")
print(country.span.text)

wine_type = product.find(class_="ProductDisplay-type")
print(wine_type.span.text)

wine_description = product.find(class_="ProductDisplay-descriptionText")
print(wine_description.text)
      
# print(product_name_a.prettify())
# Out:
# Pérez Cruz Limited Edition D.O. Valle del Maipo Cabernet Franc 2016
# https://wine.com.br/vinhos/perez-cruz-limited-edition-d-o-valle-del-maipo-cabernet-franc-2016/prod20081.html
# Chile
# tinto
# Frutado, taninos presentes, médio corpo, fresco, amadeirado, especiarias

# %%
# Buscando Notas e numero de avaliações
import re

wine_rating = product.find('div',class_='Rating')
wine_evaluation_tag = wine_rating.find('evaluation-tag')
if (wine_evaluation_tag):
    wine_evaluation = re.compile(r"\d.\d").search(wine_evaluation_tag.prettify()).group()
    wine_rating_count = re.search(r"\d+", wine_rating.find(class_='Rating-count').text).group()
else:
    wine_evaluation = None
    wine_rating_count = 0

print(str(wine_rating))
print(wine_evaluation)
print(wine_rating_count)
# Out:
# <div class="Rating">
# <div class="Rating-stars">
# <div class="vue-evaluation-tag">
# <evaluation-tag :evaluation="4.0"></evaluation-tag>
# </div>
# </div>
# <a class="Rating-count" href="/vinhos/perez-cruz-limited-edition-d-o-valle-del-maipo-cabernet-franc-2016/prod20081.html#Comments">(7)</a>
# </div>
# 4.0
# 7

# %%
# Buscando Preço

price_box = product.find(class_="ProductDisplay-priceBox")

lowest_price = price_box.find(class_="Price--lowestPrice").find(class_="Price-raw").text
full_price = price_box.find(class_="Price--fullPrice").find(class_="Price-raw").text
print(lowest_price)
print(full_price)

discount = 1-float(lowest_price)/float(full_price)
print(discount)
# Out:
# 145.76
# 180.90
# 0.1942509673852958

# %%
# Buscando Número de Páginas

pages_list = soup.find('div', class_='Pagination').ul.find_all('li')
int(pages_list[len(pages_list)-1].a.text)
# Out:
# 47

# %%
# Juntando tudo para processar a lista de uma só página

wine_list = soup.find('div', class_='ProductList-content').ul.find_all('li')

for wine_item in wine_list:
    wine = wine_item.find('article', class_='ProductDisplay')

    wine_name = wine.find('div', class_='ProductDisplay-name').a['title']
    wine_link = "https://wine.com.br" + wine.find('div', class_='ProductDisplay-name').a['href']
    wine_country = wine.find(class_="Country").span.text
    wine_type = wine.find(class_="ProductDisplay-type").span.text
    wine_description = wine.find(class_="ProductDisplay-descriptionText").text
    
    wine_rating = wine.find('div',class_='Rating')
    wine_evaluation_tag = wine_rating.find('evaluation-tag')
    if (wine_evaluation_tag):
        wine_evaluation = re.compile(r"\d.\d").search(wine_evaluation_tag.prettify()).group()
        wine_rating_count = re.search(r"\d+", wine_rating.find(class_='Rating-count').text).group()
    else:
        wine_evaluation = None
        wine_rating_count = 0
    
    price_box = wine.find(class_="ProductDisplay-priceBox")

    lowest_price = price_box.find(class_="Price--lowestPrice").find(class_="Price-raw").text
    full_price = price_box.find(class_="Price--fullPrice").find(class_="Price-raw").text
    discount = 1-float(lowest_price)/float(full_price)
    
    
    print(wine_name,";", wine_evaluation, ";", wine_rating_count, ";", wine_country, ";", wine_type, ";", lowest_price, ";", full_price, ";", discount,";", wine_description, ";", wine_link)
# Out:
# Pérez Cruz Limited Edition D.O. Valle del Maipo Cabernet Franc 2016 ; 4.0 ; 7 ; Chile ; tinto ; 145.76 ; 180.90 ; 0.1942509673852958 ; Frutado, taninos presentes, médio corpo, fresco, amadeirado, especiarias ; https://wine.com.br/vinhos/perez-cruz-limited-edition-d-o-valle-del-maipo-cabernet-franc-2016/prod20081.html
# Finca La Chamiza Martín Alsina Malbec 2014 ; None ; 0 ; Argentina ; tinto ; 292.82 ; 495.90 ; 0.4095180479935471 ; Frutado, amadeirado, corpo de médio para encorpado, taninos presentes, acidez agradável ; https://wine.com.br/vinhos/finca-la-chamiza-martin-alsina-malbec-2014/prod20028.html
# Domaine L'Ostal Cazes Grand Vin 2015 ; None ; 0 ; França ; tinto ; 258.71 ; 335.90 ; 0.22980053587377192 ; Encorpado, boa acidez, taninos macios ; https://wine.com.br/vinhos/domaine-l-ostal-cazes-grand-vin-2015/prod20143.html
# Echo de Lynch-Bages A.O.C. Pauillac 2014 ; None ; 0 ; França ; tinto ; 721.06 ; 1056.90 ; 0.3177594852871607 ; Exuberante, encorpado, taninos presentes, boa acidez, final longo ; https://wine.com.br/vinhos/echo-de-lynch-bages-a-o-c-pauillac-2014/prod20208.html
# Château La Fleur-Pétrus A.O.C. Pomerol 2006 ; None ; 0 ; França ; tinto ; 3614.00 ; 6036.90 ; 0.40134837416554847 ; Aveludado, complexo, boa acidez, corpo de médio para encorpado ; https://wine.com.br/vinhos/chateau-la-fleur-petrus-a-o-c-pomerol-2006/prod20202.html
# Viña Vilano Roble Tempranillo 2016 ; 2.5 ; 10 ; Espanha ; tinto ; 84.59 ; 167.90 ; 0.4961882072662299 ; Encorpado, taninos presentes, boa acidez, harmônico, frutado, amadeirado ; https://wine.com.br/vinhos/vina-vilano-roble-tempranillo-2016/prod20270.html
# La Casica del Abuelo D.O. Alicante 2016 ; 4.0 ; 21 ; Espanha ; tinto ; 104.59 ; 157.90 ; 0.33761874604179865 ; Corpo de médio para encorpado, taninos presentes, acidez agradável, frutado, amadeirado ; https://wine.com.br/vinhos/la-casica-del-abuelo-d-o-alicante-2016/prod20267.html
# Ulysses Napa Valley 2014 ; None ; 0 ; Estados Unidos ; tinto ; 2059.88 ; 3041.90 ; 0.32283112528353985 ; Intenso, encorpado, taninos presentes, boa acidez, longo, complexo ; https://wine.com.br/vinhos/ulysses-napa-valley-2014/prod20427.html
# Toro Loco Barricas & Tinajas 2016 ; 4.0 ; 5 ; Espanha ; tinto ; 151.65 ; 168.90 ; 0.10213143872113672 ; Corpo de médio para encorpado, taninos presentes, boa acidez, amadeirado ; https://wine.com.br/vinhos/toro-loco-barricas-tinajas-2016/prod20547.html

# %%
import requests
from lxml.html import fromstring
from itertools import cycle
import traceback
import timeit

def get_proxies():
    url = 'https://free-proxy-list.net/'
    start = timeit.timeit()
    response = requests.get(url)
    end = timeit.timeit()
    print(end - start)
    parser = fromstring(response.text)
    #print (response.text)
    proxies = set()
    for i in parser.xpath('//tbody/tr')[:20]:
        #print(i.xpath('.//td[7][contains(text(),"yes")]'))
        if i.xpath('.//td[7][contains(text(),"yes")]'):
            proxy = ":".join([i.xpath('.//td[1]/text()')[0], i.xpath('.//td[2]/text()')[0]])
            proxies.add(proxy)
    return proxies

proxies = get_proxies()
print(proxies)
proxy_pool = cycle(proxies)

url = 'https://httpbin.org/ip'
for i in range(1,11):
    #Get a proxy from the pool
    proxy = next(proxy_pool)
    print("Request #%d"%i)
    try:
        start = timeit.timeit()
        response = requests.get(url,proxies={"http": proxy, "https": proxy})
        end = timeit.timeit()
        print (end - start)
        print(response.json())
    except:
        #Most free proxies will often get connection errors. You will have retry the entire request using another proxy to work. 
        #We will just skip retries as its beyond the scope of this tutorial and we are only downloading a single url 
        print("Skipping. Connnection error")
# Out:
# -0.0018271599992658594
# {'103.83.116.210:55443', '109.239.243.211:23500', '123.195.152.139:32287', '194.8.146.167:50510', '27.255.13.134:49328'}
# Request #1
# -0.0012395980002111173
# {'origin': '103.15.240.89'}
# Request #2
# Skipping. Connnection error
# Request #3
# Skipping. Connnection error
# Request #4
# Skipping. Connnection error
# Request #5
# Skipping. Connnection error
# Request #6
# Skipping. Connnection error
# Request #7
# 0.0003484030003164662
# {'origin': '109.239.243.211'}
# Request #8
# Skipping. Connnection error
# Request #9
# -0.0026197279994448763
# {'origin': '194.8.146.167'}
# Request #10
# Skipping. Connnection error

# %% [markdown]
# ### 1.2. Sistema Winescrapper

# %%
# Webscrapper do Site da Wine
# Cabeçalhos e Imports

from bs4 import BeautifulSoup as bs
import pandas as pd
import requests
import re
import time

URL_RAIZ="https://www.wine.com.br"
URL_BASE = URL_RAIZ+"/vinhos/tinto/cVINHOS-atTIPO_{0}-p{1}.html"


HEADERS = {
    'user-agent': ('Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 '
                   '(KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36'),
    'Connection':'close'
}

# %%
# Funções

def get_num_pages(soup):
    
    pages_list = soup.find('div', class_='Pagination').ul.find_all('li')
    num_pages = int(pages_list[len(pages_list)-1].a.text) + 1
    
    return num_pages

def scrape_soup(soup):
    
    list_name=[]
    list_link, list_country, list_type, list_description= [], [], [], []
    list_evaluation, list_rating_count= [], []
    list_lowest_price, list_full_price, list_discount= [], [], []
    
    wine_list = soup.find('div', class_='ProductList-content').ul.find_all('li')

    for wine_item in wine_list:
        
        try:
            wine = wine_item.find('article', class_='ProductDisplay')

            wine_name = wine.find('div', class_='ProductDisplay-name').a['title']
            wine_link = "wine.com.br" + wine.find('div', class_='ProductDisplay-name').a['href']
            wine_country = wine.find(class_="Country").span.text
            wine_type = wine.find(class_="ProductDisplay-type").span.text
            wine_description = wine.find(class_="ProductDisplay-descriptionText").text
        
            wine_rating = wine.find('div',class_='Rating')
            wine_evaluation_tag = wine_rating.find('evaluation-tag')
            if (wine_evaluation_tag):
                wine_evaluation = float(re.compile(r"\d.\d").search(wine_evaluation_tag.prettify()).group())
                wine_rating_count = float(re.search(r"\d+", wine_rating.find(class_='Rating-count').text).group())
            else:
                wine_evaluation = 0
                wine_rating_count = 0
    
        
            price_box = wine.find(class_="ProductDisplay-priceBox")

            lowest_price = float(price_box.find(class_="Price--lowestPrice").find(class_="Price-raw").text)
            full_price = float(price_box.find(class_="Price--fullPrice").find(class_="Price-raw").text)
            discount = 1-float(lowest_price)/float(full_price)
        except:
            if wine_name:
                print('skip incomplete item:', wine_name)
                continue
            else:
                print("skip incomplete item: no name")
                continue
        
        list_name.append(wine_name)
        list_link.append(wine_link)
        list_country.append(wine_country)
        list_type.append(wine_type)
        list_description.append(wine_description)
        
        list_evaluation.append(wine_evaluation)
        list_rating_count.append(wine_rating_count)

        list_lowest_price.append(lowest_price)
        list_full_price.append(full_price)
        list_discount.append(discount)
        
        ###print(wine_name,";", wine_evaluation, ";", wine_rating_count, ";", wine_country, ";", wine_type, ";", lowest_price, ";", full_price, ";", discount,";", wine_link)
    
    df = pd.DataFrame({
        'wine_name': list_name,
        'link': list_link,
        'country': list_country,
        'type': list_type,
        'description': list_description,
        'evaluation': list_evaluation,
        'rating_count': list_rating_count,
        'lowest_price': list_lowest_price,
        'full_price': list_full_price,
        'discount': list_discount
    })
    
    return df
        
    

def get_soup(page_url, retry_count=0):
    
    session= requests.Session()
    session.trust_env = False
    
    print("Iniciando session_get")
    
    try:
        response = session.get(page_url, headers=HEADERS)
        print("\nScraping page:",page_url," = ", response)
        soup = bs(response.content, 'html.parser')
        return soup
    except:
        print("Get falhou")
        retry_count += 1
        if retry_count <= 3:
            print("retry get")
            session = requests.Session()
            get_soup(page_url, retry_count)
        else:
            raise

# %%
# Módulo Principal - Processamento do Site

wine_df = pd.DataFrame(columns=['wine_name','link','country','type','description','evaluation','rating_count','lowest_price','full_price','discount'])

tipos_de_vinho = ['TINTO','BRANCO']

for tipo in tipos_de_vinho:

    pages_to_scrape = 4

    current_page = 1


    while (current_page != pages_to_scrape):
    
        print("vinhos {}: Iniciando get_soup pagina {}").format(tipo, current_page)
    
        wine_soup = get_soup(URL_BASE.format(tipo, current_page))
    
        if current_page == 1:
            pages_to_scrape = get_num_pages(wine_soup)
    
        new_df = scrape_soup(wine_soup)
        wine_df= wine_df.append(new_df, ignore_index=True)
    
        ###print(current_page)
    
        time.sleep(10)
        current_page += 1
    
print("Scrape finished.")
wine_df
# Out:
# Iniciando get_soup pagina 1
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p1.html  =  <Response [200]>
# Iniciando get_soup pagina 2
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p2.html  =  <Response [200]>
# Iniciando get_soup pagina 3
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p3.html  =  <Response [200]>
# Iniciando get_soup pagina 4
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p4.html  =  <Response [200]>
# Iniciando get_soup pagina 5
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p5.html  =  <Response [200]>
# Iniciando get_soup pagina 6
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p6.html  =  <Response [200]>
# Iniciando get_soup pagina 7
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p7.html  =  <Response [200]>
# Iniciando get_soup pagina 8
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p8.html  =  <Response [200]>
# Iniciando get_soup pagina 9
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p9.html  =  <Response [200]>
# Iniciando get_soup pagina 10
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p10.html  =  <Response [200]>
# Iniciando get_soup pagina 11
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p11.html  =  <Response [200]>
# skip incomplete item: WineBox Miguel Torres 3 Garrafas
# Iniciando get_soup pagina 12
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p12.html  =  <Response [200]>
# skip incomplete item: WineBox Partridge
# skip incomplete item: WineBox Família Vik - 6 garrafas
# skip incomplete item: Winebox Trio Novas Estrelas
# Iniciando get_soup pagina 13
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p13.html  =  <Response [200]>
# skip incomplete item: WineBox Mãe de primeira viagem
# Iniciando get_soup pagina 14
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p14.html  =  <Response [200]>
# skip incomplete item: WineBox Root: 1 - 4 garrafas
# skip incomplete item: Winebox Carpineto Riserva D.O.C.G. Chianti Classico 2015
# skip incomplete item: WineBox Apothic Crush + Taças
# Iniciando get_soup pagina 15
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p15.html  =  <Response [200]>
# Iniciando get_soup pagina 16
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p16.html  =  <Response [200]>
# skip incomplete item: Winebox Premium
# skip incomplete item: WineBox O Melhor do Velho Mundo
# Iniciando get_soup pagina 17
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p17.html  =  <Response [200]>
# Iniciando get_soup pagina 18
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p18.html  =  <Response [200]>
# Iniciando get_soup pagina 19
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p19.html  =  <Response [200]>
# skip incomplete item: WineBox Família Toro Loco
# Iniciando get_soup pagina 20
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p20.html  =  <Response [200]>
# Iniciando get_soup pagina 21
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p21.html  =  <Response [200]>
# Iniciando get_soup pagina 22
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p22.html  =  <Response [200]>
# Iniciando get_soup pagina 23
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p23.html  =  <Response [200]>
# Iniciando get_soup pagina 24
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p24.html  =  <Response [200]>
# Iniciando get_soup pagina 25
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p25.html  =  <Response [200]>
# Iniciando get_soup pagina 26
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p26.html  =  <Response [200]>
# skip incomplete item: WineBox Italianos de Peso
# skip incomplete item: WineBox Eu Amo Tintos
# Iniciando get_soup pagina 27
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p27.html  =  <Response [200]>
# skip incomplete item: WineBox Mosaiko - 3 garrafas
# Iniciando get_soup pagina 28
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p28.html  =  <Response [200]>
# skip incomplete item: WineBox Quarteto América do Sul
# Iniciando get_soup pagina 29
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p29.html  =  <Response [200]>
# skip incomplete item: WineBox  Queridinhos America do Sul
# skip incomplete item: WineBox Nossos Vizinhos
# Iniciando get_soup pagina 30
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p30.html  =  <Response [200]>
# Iniciando get_soup pagina 31
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p31.html  =  <Response [200]>
# Iniciando get_soup pagina 32
# Iniciando session_get
#
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p32.html  =  <Response [200]>
# skip incomplete item: WineBox o Amor está no Ar
# skip incomplete item: WineBox Sexteto América
# Scrape finished.
#                                              wine_name  \
# 0                      Chateau Oumsiyat Red Jaspe 2014
# 1        Protos Roble D.O. Ribeira Del Duero 1.5L 2017
# 2    Fantinel Borgo Tesis Doc Grave Cabernet Sauvig...
# 3                      Urmeneta Reserva Carménère 2018
# 4       Bridlewood Paso Robles Cabernet Sauvignon 2017
# ..                                                 ...
# 259  Enclos du Wine Hunter Saint-Emilion Grand Cru ...
# 260              Barahonda Campo Arriba Old Vines 2015
# 261                              Chateau Fongaban 2016
# 262  Toro Loco D.O.P. Utiel-Requena Tinto Superior ...
# 263      Señorío de Ayud Cabernet Sauvignon Syrah 2018
#
#                                                   link         country   type  \
# 0    wine.com.br/vinhos/chateau-oumsiyat-red-jaspe-...          Líbano  tinto
# 1    wine.com.br/vinhos/protos-roble-d-o-ribeira-de...         Espanha  tinto
# 2    wine.com.br/vinhos/fantinel-borgo-tesis-doc-gr...          Itália  tinto
# 3    wine.com.br/vinhos/urmeneta-reserva-carmenere-...           Chile  tinto
# 4    wine.com.br/vinhos/bridlewood-paso-robles-cabe...  Estados Unidos  tinto
# ..                                                 ...             ...    ...
# 259  wine.com.br/vinhos/enclos-du-wine-hunter-saint...          França  tinto
# 260  wine.com.br/vinhos/barahonda-campo-arriba-old-...         Espanha  tinto
# 261  wine.com.br/vinhos/chateau-fongaban-2016/prod1...          França  tinto
# 262  wine.com.br/vinhos/toro-loco-d-o-p-utiel-reque...         Espanha  tinto
# 263  wine.com.br/vinhos/senorio-de-ayud-cabernet-sa...         Espanha  tinto
#
#                                            description  evaluation  \
# 0                         Encorpado, robusto e frutado         3.0
# 1    Médio corpo, taninos macios, acidez agradável,...         0.0
# 2    Tem bom corpo, taninos presentes, boa acidez, ...         4.5
# 3    Frutado, vegetal, médio corpo, taninos macios,...         4.0
# 4    Médio corpo, fresco, taninos macios, bom final...         4.0
# ..                                                 ...         ...
# 259       Encorpado, saboroso e com taninos aveludados         4.0
# 260  médio corpo, harmônico, acidez agradável, tani...         4.0
# 261  Estruturado, taninos presentes, acidez agradáv...         3.0
# 262  Frutado, corpo de leve para médio, taninos mac...         4.5
# 263  Frutado, médio corpo, acidez agradável, tanino...         4.5
#
#      rating_count  lowest_price  full_price  discount
# 0             6.0        161.06       195.9  0.177846
# 1             0.0        237.53       372.9  0.363020
# 2             4.0         77.53       139.9  0.445818
# 3             2.0         74.90        74.9  0.000000
# 4             9.0        152.82       165.9  0.078843
# ..            ...           ...         ...       ...
# 259           3.0        283.41       414.9  0.316920
# 260          30.0         92.82       151.9  0.388940
# 261           1.0        128.12       190.9  0.328863
# 262         629.0         43.41        54.9  0.209290
# 263          94.0         52.82        60.9  0.132677
#
# [264 rows x 10 columns]

# %%
# Análise do dados

wine_deals = wine_df.loc[(wine_df.rating_count>=36) & (wine_df.evaluation >= 4.2) & (wine_df.lowest_price < 66.20)]
wine_deals
# Out:
#                                              wine_name  \
# 226            Corello D.O.C. Sicília Nero dAvola 2017
# 239                       Partridge Flying Malbec 2019
# 262  Toro Loco D.O.P. Utiel-Requena Tinto Superior ...
# 263      Señorío de Ayud Cabernet Sauvignon Syrah 2018
#
#                                                   link    country   type  \
# 226  wine.com.br/vinhos/corello-d-o-c-sicilia-nero-...     Itália  tinto
# 239  wine.com.br/vinhos/partridge-flying-malbec-201...  Argentina  tinto
# 262  wine.com.br/vinhos/toro-loco-d-o-p-utiel-reque...    Espanha  tinto
# 263  wine.com.br/vinhos/senorio-de-ayud-cabernet-sa...    Espanha  tinto
#
#                                            description  evaluation  \
# 226  Corpo de leve para médio, fresco, taninos sedosos         4.5
# 239  Corpo de leve para médio, frutado, acidez agra...         4.5
# 262  Frutado, corpo de leve para médio, taninos mac...         4.5
# 263  Frutado, médio corpo, acidez agradável, tanino...         4.5
#
#      rating_count  lowest_price  full_price  discount
# 226         102.0         62.24        75.9  0.179974
# 239          74.0         51.65        59.9  0.137730
# 262         629.0         43.41        54.9  0.209290
# 263          94.0         52.82        60.9  0.132677

# %%
wine_exotic = wine_df.loc[~wine_df.country.isin(['Chile','França','Espanha','Argentina','Itália','Portugal','Brasil','Estados Unidos','Uruguai'])]
wine_exotic.loc[wine_exotic.country == 'China']

#wine_exotic.iloc[2].link
# Out:
# Empty DataFrame
# Columns: [wine_name, link, country, type, description, evaluation, rating_count, lowest_price, full_price, discount]
# Index: []

# %%
# Exemplo do uso de Describe
wine_df.lowest_price.describe()
# Out:
# count      264.000000
# mean       677.484394
# std       1924.731806
# min         41.060000
# 25%         82.240000
# 50%        124.745000
# 75%        291.940000
# max      15870.470000
# Name: lowest_price, dtype: float64

# %%
# Mais um exemplo de Describe

wine_df.loc[wine_df.evaluation > 0].describe()
# Out:
#        evaluation  rating_count  lowest_price    full_price    discount
# count  195.000000    195.000000    195.000000    195.000000  195.000000
# mean     4.046154     26.692308    286.224000    397.274462    0.205881
# std      0.662254     53.827691    926.365633   1429.842863    0.125025
# min      1.000000      1.000000     41.060000     49.900000    0.000000
# 25%      4.000000      3.000000     76.350000     97.900000    0.128630
# 50%      4.000000     10.000000     95.180000    129.290000    0.208700
# 75%      4.500000     33.000000    182.220000    227.400000    0.289110
# max      5.000000    629.000000   9303.410000  14794.900000    0.484785

# %%
#Exemplo de funções de sumário

print(wine_df.country.describe())
print(wine_df.rating_count.mean())
print(wine_df.country.unique())
# Out:
# count        264
# unique        13
# top       França
# freq          69
# Name: country, dtype: object
# 19.71590909090909
# ['Líbano' 'Espanha' 'Itália' 'Chile' 'Estados Unidos' 'Portugal' 'França'
#  'Argentina' 'África do Sul' 'Alemanha' 'Áustria' 'Uruguai' 'Austrália']

# %%
# Exemplo de groupby
wine_df.groupby('country').lowest_price.min()
# Out:
# country
# Alemanha           88.12
# Argentina          46.94
# Austrália          94.00
# Chile              48.90
# Espanha            41.06
# Estados Unidos     90.47
# França             52.82
# Itália             52.82
# Líbano            161.06
# Portugal           58.71
# Uruguai           225.76
# África do Sul      64.59
# Áustria           110.47
# Name: lowest_price, dtype: float64

# %%
# Exemplo de min
wine_deals.groupby('country').lowest_price.min()
# Out:
# country
# Argentina    51.65
# Espanha      43.41
# Itália       62.24
# Name: lowest_price, dtype: float64

# %%
# Exemplo de Apply
wine_df.groupby(['country','type']).apply(lambda df: df.loc[df.rating_count.idxmax()])
# Out:
#                                                               wine_name  \
# country        type
# Alemanha       tinto  Ernst Loosen Winemakers Select Pfalz Edition P...
# Argentina      tinto  Partridge Reserva Edición Limitada Cabernet Sa...
# Austrália      tinto                         Oxford Landing Shiraz 2017
# Chile          tinto     Pérez Cruz GSM D.O. Valle del Maipo Andes 2016
# Espanha        tinto  Toro Loco D.O.P. Utiel-Requena Tinto Superior ...
# Estados Unidos tinto                                   Apothic Red 2017
# França         tinto                                           Beaupont
# Itália         tinto                                 Campo Al Moro 2016
# Líbano         tinto                    Chateau Oumsiyat Red Jaspe 2014
# Portugal       tinto             Quinta de São João Cuvée RB Tinto 2017
# Uruguai        tinto  Viñedo de los Vientos Angel's Cuvée Ripasso de...
# África do Sul  tinto         Lievland Vineyards Bush Vine Pinotage 2017
# Áustria        tinto                          Zweigelt Classic Red 2017
#
#                                                                    link  \
# country        type
# Alemanha       tinto  wine.com.br/vinhos/ernst-loosen-winemakers-sel...
# Argentina      tinto  wine.com.br/vinhos/partridge-reserva-edicion-l...
# Austrália      tinto  wine.com.br/vinhos/oxford-landing-shiraz-2017/...
# Chile          tinto  wine.com.br/vinhos/perez-cruz-gsm-d-o-valle-de...
# Espanha        tinto  wine.com.br/vinhos/toro-loco-d-o-p-utiel-reque...
# Estados Unidos tinto  wine.com.br/vinhos/apothic-red-2017/prod22747....
# França         tinto         wine.com.br/vinhos/beaupont/prod22980.html
# Itália         tinto  wine.com.br/vinhos/campo-al-moro-2016/prod1894...
# Líbano         tinto  wine.com.br/vinhos/chateau-oumsiyat-red-jaspe-...
# Portugal       tinto  wine.com.br/vinhos/quinta-de-sao-joao-cuvee-rb...
# Uruguai        tinto  wine.com.br/vinhos/vinedo-de-los-vientos-angel...
# África do Sul  tinto  wine.com.br/vinhos/lievland-vineyards-bush-vin...
# Áustria        tinto  wine.com.br/vinhos/zweigelt-classic-red-2017/p...
#
#                              country   type  \
# country        type
# Alemanha       tinto        Alemanha  tinto
# Argentina      tinto       Argentina  tinto
# Austrália      tinto       Austrália  tinto
# Chile          tinto           Chile  tinto
# Espanha        tinto         Espanha  tinto
# Estados Unidos tinto  Estados Unidos  tinto
# França         tinto          França  tinto
# Itália         tinto          Itália  tinto
# Líbano         tinto          Líbano  tinto
# Portugal       tinto        Portugal  tinto
# Uruguai        tinto         Uruguai  tinto
# África do Sul  tinto   África do Sul  tinto
# Áustria        tinto         Áustria  tinto
#
#                                                             description  \
# country        type
# Alemanha       tinto             Leve, acidez presente, taninos sedosos
# Argentina      tinto  Médio corpo, boa acidez, taninos macios, cacau...
# Austrália      tinto  Corpo de leve para médio, taninos macios, boa ...
# Chile          tinto  Corpo de médio para encorpado, frutado, especi...
# Espanha        tinto  Frutado, corpo de leve para médio, taninos mac...
# Estados Unidos tinto  Leve para médio corpo, acidez agradável, tanin...
# França         tinto              Corpo médio, frutado e taninos macios
# Itália         tinto                Frutado, taninos macios, boa acidez
# Líbano         tinto                       Encorpado, robusto e frutado
# Portugal       tinto      Médio corpo, fresco, taninos sedosos, frutado
# Uruguai        tinto  Encorpado, taninos presentes, acidez agradável...
# África do Sul  tinto   Frutado, médio corpo, taninos macios, boa acidez
# Áustria        tinto                        Robusto, taninos aveludados
#
#                       evaluation  rating_count  lowest_price  full_price  \
# country        type
# Alemanha       tinto         4.0          24.0         96.35       119.9
# Argentina      tinto         4.0          82.0         70.47        79.9
# Austrália      tinto         3.5          14.0         94.00       120.9
# Chile          tinto         4.5         122.0         88.12        90.9
# Espanha        tinto         4.5         629.0         43.41        54.9
# Estados Unidos tinto         4.5          39.0        108.12       141.9
# França         tinto         4.0         188.0         52.82        53.9
# Itália         tinto         4.0         186.0         52.82        64.9
# Líbano         tinto         3.0           6.0        161.06       195.9
# Portugal       tinto         4.0         135.0         58.71        73.9
# Uruguai        tinto         5.0          23.0        225.76       399.9
# África do Sul  tinto         4.0          85.0         97.53       135.9
# Áustria        tinto         3.0           9.0        110.47       159.9
#
#                       discount
# country        type
# Alemanha       tinto  0.196414
# Argentina      tinto  0.118023
# Austrália      tinto  0.222498
# Chile          tinto  0.030583
# Espanha        tinto  0.209290
# Estados Unidos tinto  0.238055
# França         tinto  0.020037
# Itália         tinto  0.186133
# Líbano         tinto  0.177846
# Portugal       tinto  0.205548
# Uruguai        tinto  0.435459
# África do Sul  tinto  0.282340
# Áustria        tinto  0.309131

# %%
# Exemplo de sort

sorted_wines = wine_deals.sort_values(by=['lowest_price','evaluation'])
sorted_wines
# Out:
#                                              wine_name  \
# 262  Toro Loco D.O.P. Utiel-Requena Tinto Superior ...
# 239                       Partridge Flying Malbec 2019
# 263      Señorío de Ayud Cabernet Sauvignon Syrah 2018
# 226            Corello D.O.C. Sicília Nero dAvola 2017
#
#                                                   link    country   type  \
# 262  wine.com.br/vinhos/toro-loco-d-o-p-utiel-reque...    Espanha  tinto
# 239  wine.com.br/vinhos/partridge-flying-malbec-201...  Argentina  tinto
# 263  wine.com.br/vinhos/senorio-de-ayud-cabernet-sa...    Espanha  tinto
# 226  wine.com.br/vinhos/corello-d-o-c-sicilia-nero-...     Itália  tinto
#
#                                            description  evaluation  \
# 262  Frutado, corpo de leve para médio, taninos mac...         4.5
# 239  Corpo de leve para médio, frutado, acidez agra...         4.5
# 263  Frutado, médio corpo, acidez agradável, tanino...         4.5
# 226  Corpo de leve para médio, fresco, taninos sedosos         4.5
#
#      rating_count  lowest_price  full_price  discount
# 262         629.0         43.41        54.9  0.209290
# 239          74.0         51.65        59.9  0.137730
# 263          94.0         52.82        60.9  0.132677
# 226         102.0         62.24        75.9  0.179974

# %%
# Exemplo de iterator em DataFrame

for index, row in sorted_wines.iterrows():
    print(row.wine_name, "\t", row.link)
# Out:
# Toro Loco D.O.P. Utiel-Requena Tinto Superior 2018 	 wine.com.br/vinhos/toro-loco-d-o-p-utiel-requena-tinto-superior-2018/prod23299.html
# Partridge Flying Malbec 2019 	 wine.com.br/vinhos/partridge-flying-malbec-2019/prod23315.html
# Señorío de Ayud Cabernet Sauvignon Syrah 2018 	 wine.com.br/vinhos/senorio-de-ayud-cabernet-sauvignon-syrah-2018/prod22834.html
# Corello D.O.C. Sicília Nero dAvola 2017 	 wine.com.br/vinhos/corello-d-o-c-sicilia-nero-davola-2017/prod22056.html

# %% [markdown]
# ### 1.3. Análise Descritiva - Wine

# %%
# Gráficos

import matplotlib.pyplot as plt

#wine_df.boxplot(column=wine_df.groupby('country'))
wine_df.groupby('country')['lowest_price'].describe()
# Out:
#                 count         mean          std     min       25%      50%  \
# country
# Alemanha          2.0    92.235000     5.819489   88.12   90.1775   92.235
# Argentina        26.0   138.206923   101.050780   46.94   70.4700  101.060
# Austrália         2.0    94.000000     0.000000   94.00   94.0000   94.000
# Chile            38.0   184.585263   213.778703   48.90   76.3500   93.410
# Espanha          42.0   121.894762   127.195554   41.06   69.0750   86.355
# Estados Unidos   23.0   850.327826  1912.956175   90.47  135.1750  188.120
# França           69.0  1861.073188  3314.595539   52.82  108.1200  264.590
# Itália           24.0   256.990000   239.139957   52.82   85.4725  168.115
# Líbano            2.0   161.060000     0.000000  161.06  161.0600  161.060
# Portugal         22.0   243.364545   283.985539   58.71   81.3550  124.645
# Uruguai           1.0   225.760000          NaN  225.76  225.7600  225.760
# África do Sul    12.0   217.040833   239.861560   64.59   87.2375   95.180
# Áustria           1.0   110.470000          NaN  110.47  110.4700  110.470
#
#                       75%       max
# country
# Alemanha          94.2925     96.35
# Argentina        185.1450    451.65
# Austrália         94.0000     94.00
# Chile            180.7375   1058.71
# Espanha          129.4000    777.53
# Estados Unidos   365.1750   8938.71
# França          1775.1800  15870.47
# Itália           313.9975    941.06
# Líbano           161.0600    161.06
# Portugal         299.8800   1225.76
# Uruguai          225.7600    225.76
# África do Sul    193.4125    705.76
# Áustria          110.4700    110.47

# %%
wine_df.loc[(wine_df.evaluation > 3.1) & (wine_df.lowest_price < 200.0) & (wine_df.rating_count > 34.0)].boxplot(by='country',column=['lowest_price'], figsize=(15,10), patch_artist=True)

# %%
wine_plot = wine_df.loc[(wine_df.evaluation > 3.1) & (wine_df.lowest_price < 1000.0) & (wine_df.rating_count > 34.0)]
wine_plot.boxplot(by='evaluation',column=['lowest_price'], figsize=(15,10), patch_artist=True)

# %%
wine_df.evaluation.corr(wine_df.lowest_price)
# Out:
# -0.3105601653067896

# %% [markdown]
# ## Parte 2 - Busca no Vivino
#
# ### 2.1. Testes Individuais

# %% [markdown]
# #### URL Encoding para buscar no Vivino

# %%
import urllib.parse

wine_deals = wine_df.loc[(wine_df.rating_count>=36) & (wine_df.evaluation >= 4.2)]
sorted_wines = wine_deals.sort_values(by=['lowest_price','evaluation'])

#row = next(sorted_wines.iterrows())[1]
#Pegando o segundo da lista
row = sorted_wines.iloc[0]

query_url = urllib.parse.quote(row.wine_name)
row.wine_name

#for index, row in sorted_wines.iterrows():
#    query_url = urllib.parse.quote(row.wine_name)
#    print(query_url.replace("%20","+"), "\t", 'https://'+row.link)
# Out:
# 'Toro Loco D.O.P. Utiel-Requena Tinto Superior 2018'

# %%
new_url = 'https://www.vivino.com/search/wines?q='+query_url.replace("%20","+")
new_url
# Out:
# 'https://www.vivino.com/search/wines?q=Toro+Loco+D.O.P.+Utiel-Requena+Tinto+Superior+2018'

# %%
row.link
# Out:
# 'wine.com.br/vinhos/toro-loco-d-o-p-utiel-requena-tinto-superior-2018/prod23299.html'

# %% [markdown]
# #### Busca no Vivino

# %%
vivino_soup = get_soup(new_url)

#print(vivino_soup.body.prettify())

# %%
vivino_search_item = vivino_soup.find('div', class_="wine-card__content")

vivino_name = vivino_search_item.find('span', class_="wine-card__name").text.replace("\n","")
print(vivino_name)

vivino_average_score_txt = vivino_search_item.find('div', class_="average__number").text.replace("\n","")
try:
    vivino_average_score = float(vivino_average_score_txt.replace(",","."))
except:
    vivino_average_score = vivino_average_score_txt
print(vivino_average_score)

try:
    vivino_rating_txt = vivino_search_item.find('div', class_="average__stars").text
    vivino_rating = float(re.search(r"\d+",vivino_rating_txt).group())
except:
    vivino_rating = None
print(vivino_rating)

vivino_price = vivino_search_item.find('div', class_="wine-price")
vivino_price

# %% [markdown]
# #### Tentando com Selenium

# %%
from selenium import webdriver

browser = webdriver.Chrome('C:\\Users\\gmendonc\\Dev\\Scrapper\\winescrapper\\chromedriver_win32\\chromedriver')
browser.get(new_url)

vivino_soup_byselenium = bs(browser.page_source,'html.parser')

vivino_search_item = vivino_soup_byselenium.find('div', class_="wine-card__content")

# %%
vivino_name_card = vivino_search_item.find('span', class_="wine-card__name")
vivino_name = vivino_name_card.text.replace("\n","")
print(vivino_name)

vivino_link = 'www.vivino.com'+vivino_name_card.a['href']
print(vivino_link)

vivino_average_score_txt = vivino_search_item.find('div', class_="average__number").text.replace("\n","")
try:
    vivino_average_score = float(vivino_average_score_txt.replace(",","."))
except:
    vivino_average_score = vivino_average_score_txt
print(vivino_average_score)

try:
    vivino_rating_txt = vivino_search_item.find('div', class_="average__stars").text
    vivino_rating = float(re.search(r"\d+",vivino_rating_txt).group())
except:
    vivino_rating = None
print(vivino_rating)

try:
    vivino_price_txt = vivino_search_item.find('span', class_="wine-price-value").text
    vivino_price = float(vivino_price_txt.replace(",","."))
except:
    vivino_price = None
print(vivino_price)

# %%
browser.close()

# %% [markdown]
# ### 2.1. Prova de Conceito
#
# > Busca vinhos do dataframe da wine no vivino, acha os dados e cria um novo dataframe.

# %%
from selenium import webdriver
from time import perf_counter
import urllib.parse

VIVINO_SEARCH_URL = 'https://www.vivino.com/search/wines?q='

browser = webdriver.Chrome('C:\\Users\\gmendonc\\Dev\\Scrapper\\winescrapper\\chromedriver_win32\\chromedriver')

reference_df = wine_df

lst_vivino_name, lst_vivino_link, lst_vivino_score, lst_vivino_rating, lst_vivino_price = [], [], [], [], []
lst_original_name = []

for index, row in reference_df.iterrows():
    
    query_url = urllib.parse.quote(row.wine_name)
    new_url = VIVINO_SEARCH_URL+query_url.replace("%20","+")
    
    print("Searching...", new_url)
    
    start_time = perf_counter()
    
    try:
        browser.get(new_url)
        vivino_soup_byselenium = bs(browser.page_source,'html.parser')
        vivino_search_item = vivino_soup_byselenium.find('div', class_="wine-card__content")
        vivino_name_card = vivino_search_item.find('span', class_="wine-card__name")
        vivino_name = vivino_name_card.text.replace("\n","")
        lst_original_name.append(row.wine_name)
        lst_vivino_name.append(vivino_name)

        vivino_link = 'www.vivino.com'+vivino_name_card.a['href']
        lst_vivino_link.append(vivino_link)

        vivino_average_score_txt = vivino_search_item.find('div', class_="average__number").text.replace("\n","")
        try:
            vivino_average_score = float(vivino_average_score_txt.replace(",","."))
        except:
            vivino_average_score = None
        lst_vivino_score.append(vivino_average_score)

        try:
            vivino_rating_txt = vivino_search_item.find('div', class_="average__stars").text
            vivino_rating = float(re.search(r"\d+",vivino_rating_txt).group())
        except:
            vivino_rating = None
        lst_vivino_rating.append(vivino_rating)

        try:
            vivino_price_txt = vivino_search_item.find('span', class_="wine-price-value").text
            vivino_price = float(vivino_price_txt.replace(",","."))
        except:
            vivino_price = None
        lst_vivino_price.append(vivino_price)
    
        time.sleep(5)
    except:
        print("Next!")
    
    elapsed_time = perf_counter()-start_time
    print("tempo: ", elapsed_time)
        
    
browser.close()

df = pd.DataFrame({
        'wine_name' : lst_original_name,
        'vivino_name': lst_vivino_name,
        'vivino_link': lst_vivino_link,
        'vivino_score': lst_vivino_score,
        'vivino_rating': lst_vivino_rating,
        'vivino_price': lst_vivino_price,
    })

df
# Out:
# Searching... https://www.vivino.com/search/wines?q=Chateau+Oumsiyat+Red+Jaspe+2014
# tempo:  8.509169906343232
# Searching... https://www.vivino.com/search/wines?q=Protos+Roble+D.O.+Ribeira+Del+Duero+1.5L+2017
# tempo:  6.837324133163293
# Searching... https://www.vivino.com/search/wines?q=Fantinel+Borgo+Tesis+Doc+Grave+Cabernet+Sauvignon+Friuli+2017
# 262  Toro Loco El Toro Macho Orgánico Superior Tint...
# 263    Señorío de Ayud Cabernet Sauvignon - Syrah 2018
#
#                         vivino_link  vivino_score  vivino_rating  vivino_price
# 0     www.vivino.com/wines/10109800           3.8           67.0           NaN
# 1    www.vivino.com/wines/153049505           NaN            NaN           NaN
# 2    www.vivino.com/wines/151496012           3.7           37.0           NaN
# 3    www.vivino.com/wines/158170597           3.5           42.0           NaN
# 4    www.vivino.com/wines/151701888           3.8          162.0           NaN
# ..                              ...           ...            ...           ...
# 259  www.vivino.com/wines/161942183           4.3           14.0           NaN
# 260  www.vivino.com/wines/153357405           3.8          243.0           NaN
# 261  www.vivino.com/wines/145586773           3.6           85.0           NaN
# 262  www.vivino.com/wines/160870634           3.6          632.0           NaN
# 263  www.vivino.com/wines/158848586           3.5          159.0           NaN
#
# [264 rows x 6 columns]

# %%
result = pd.merge(reference_df, df, on='wine_name')
result.sort_values(by=['vivino_score','lowest_price'], ascending = False, na_position = 'last')
# Out:
#                                              wine_name  \
# 44                                       Opus One 2013
# 60   Château Mouton Rothschild Premier Grand Cru Cl...
# 56   Château Margaux Premier Grand Cru Classé A.O.C...
# 46   Château de Beaucastel Hommage à Jacques Perrin...
# 35                        Château La Fleur-Pétrus 2014
# ..                                                 ...
# 202                             La Jolie Carignan 2018
# 211                            Natana Cuvée Rouge 2018
# 118                 Altivo Classic Mendoza Malbec 2019
# 238     Altivo Classic Mendoza Cabernet Sauvignon 2019
# 233                               Urmeneta Merlot 2019
#
#                                                   link         country   type  \
# 44     wine.com.br/vinhos/opus-one-2013/prod19463.html  Estados Unidos  tinto
# 60   wine.com.br/vinhos/chateau-mouton-rothschild-p...          França  tinto
# 56   wine.com.br/vinhos/chateau-margaux-premier-gra...          França  tinto
# 46   wine.com.br/vinhos/chateau-de-beaucastel-homma...          França  tinto
# 35   wine.com.br/vinhos/chateau-la-fleur-petrus-201...          França  tinto
# ..                                                 ...             ...    ...
# 202  wine.com.br/vinhos/la-jolie-carignan-2018/prod...          França  tinto
# 211  wine.com.br/vinhos/natana-cuvee-rouge-2018/pro...   África do Sul  tinto
# 118  wine.com.br/vinhos/altivo-classic-mendoza-malb...       Argentina  tinto
# 238  wine.com.br/vinhos/altivo-classic-mendoza-cabe...       Argentina  tinto
# 233  wine.com.br/vinhos/urmeneta-merlot-2019/prod23...           Chile  tinto
#
#                                            description  evaluation  \
# 44   Complexo, exuberante, encorpado, boa acidez, t...         0.0
# 60   Suculento, harmonioso, maduro, taninos aveluda...         5.0
# 56   As frutas dominam o paladar e mesclam-se às no...         0.0
# 46   Denso, exuberante, estruturado, concentrado, b...         0.0
# 35   Complexo, elegante, corpo de médio para encorp...         4.0
# ..                                                 ...         ...
# 202  Bom corpo, acidez agradável, taninos macios, m...         3.0
# 211  Corpo entre leve e médio, acidez agradável, ta...         4.0
# 118  Corpo de leve para médio, taninos macios, acid...         0.0
# 238  Médio corpo, frutado, acidez agradável, tanino...         4.0
# 233                      Leve, fresco, taninos sedosos         0.0
#
#      rating_count  lowest_price  full_price  discount  \
# 44            0.0       8938.71     11799.9  0.242476
# 60            1.0       9303.41     14794.9  0.371175
# 56            0.0       9111.65     13324.9  0.316194
# 46            0.0       7326.94     10789.9  0.320945
# 35            1.0       4817.53      6564.9  0.266169
# ..            ...           ...         ...       ...
# 202           1.0         64.59        90.9  0.289439
# 211           1.0         64.59        90.9  0.289439
# 118           0.0         52.82        64.9  0.186133
# 238           1.0         52.82        64.9  0.186133
# 233           0.0         48.90        48.9  0.000000
#
#                                            vivino_name  \
# 44                              Opus One Opus One 2013
# 60   Château Mouton Rothschild Pauillac (Premier Gr...
# 56   Château Margaux Château Margaux (Premier Grand...
# 46   Château de Beaucastel Hommage à Jacques Perrin...
# 35                Château La Fleur-Pétrus Pomerol 2014
# ..                                                 ...
# 202                    Mommessin Lajolie Carignan 2018
# 211                   Marianne Natana Cuvée Rouge 2018
# 118    Finca Eugenio Bustos Altivo Classic Malbec 2019
# 238  Finca Eugenio Bustos Altivo Classic Cabernet S...
# 233                               Urmeneta Merlot 2019
#
#                         vivino_link  vivino_score  vivino_rating  vivino_price
# 44     www.vivino.com/wines/2794433           4.6         5386.0           NaN
# 60     www.vivino.com/wines/3085744           4.5          868.0           NaN
# 56     www.vivino.com/wines/1168755           4.5          667.0           NaN
# 46     www.vivino.com/wines/3896910           4.5          503.0           NaN
# 35     www.vivino.com/wines/4237999           4.5          182.0           NaN
# ..                              ...           ...            ...           ...
# 202  www.vivino.com/wines/161343009           NaN            NaN           NaN
# 211  www.vivino.com/wines/156410932           NaN            NaN           NaN
# 118  www.vivino.com/wines/160705257           NaN            NaN          42.0
# 238  www.vivino.com/wines/160826350           NaN            NaN           NaN
# 233  www.vivino.com/wines/159653809           NaN            NaN          42.9
#
# [264 rows x 15 columns]

# %%
result_clean = result.loc[(result.vivino_rating>=100) & (result.lowest_price <= 100.0)]
result_clean.sort_values(by=['vivino_score','lowest_price'], ascending = False, na_position = 'last')
# Out:
#                                              wine_name  \
# 134   Pérez Cruz Single Vineyard La Higuera Block 2017
# 198               Pérez Cruz Winemakers Selection 2017
# 215  Maison Bouachon Les Rabassières Vieilles A.O.C...
# 260              Barahonda Campo Arriba Old Vines 2015
# 97                            Las Moras Dadá Nº 3 2018
# ..                                                 ...
# 236                Oxford Landing Cabernet Shiraz 2016
# 170  Dark Horse The Original California Pinot Noir ...
# 53           Miguel Torres Reserva De Pueblo País 2016
# 107               CentAre Nero dAvola Sicilia DOC 2017
# 251                                           Beaupont
#
#                                                   link         country   type  \
# 134  wine.com.br/vinhos/perez-cruz-single-vineyard-...           Chile  tinto
# 198  wine.com.br/vinhos/perez-cruz-winemakers-selec...           Chile  tinto
# 215  wine.com.br/vinhos/maison-bouachon-les-rabassi...          França  tinto
# 260  wine.com.br/vinhos/barahonda-campo-arriba-old-...         Espanha  tinto
# 97   wine.com.br/vinhos/las-moras-dada-n-3-2018/pro...       Argentina  tinto
# ..                                                 ...             ...    ...
# 236  wine.com.br/vinhos/oxford-landing-cabernet-shi...       Austrália  tinto
# 25%      0.000000      0.000000     82.240000    106.900000    0.140808
# 50%      4.000000      4.000000    124.745000    159.650000    0.218507
# 75%      4.500000     22.250000    291.940000    391.400000    0.314559
# max      5.000000    629.000000  15870.470000  19271.900000    0.484785
#
#        vivino_score  vivino_rating  vivino_price
# count    228.000000     228.000000     55.000000
# mean       3.756579     848.736842    149.374909
# std        0.329197    2163.319476    156.453717
# min        2.900000      10.000000     33.000000
# 25%        3.500000      95.000000     58.000000
# 50%        3.700000     290.500000     82.000000
# 75%        4.000000     638.750000    171.000000
# max        4.600000   20156.000000    836.000000

# %%
best_deals = result.loc[(result.vivino_rating >= result.vivino_rating.median()) & (result.vivino_score >= result.vivino_score.mean()) & (result.lowest_price <= result.lowest_price.median())]
best_deals
# Out:
#                                              wine_name  \
# 21                   Witral Limited Edition Syrah 2016
# 97                            Las Moras Dadá Nº 3 2018
# 124                                  Apothic Dark 2016
# 134   Pérez Cruz Single Vineyard La Higuera Block 2017
# 198               Pérez Cruz Winemakers Selection 2017
# 215  Maison Bouachon Les Rabassières Vieilles A.O.C...
# 245                   Carnivor Cabernet Sauvignon 2016
#
#                                                   link         country   type  \
# 21   wine.com.br/vinhos/witral-limited-edition-syra...           Chile  tinto
# 97   wine.com.br/vinhos/las-moras-dada-n-3-2018/pro...       Argentina  tinto
# 124  wine.com.br/vinhos/apothic-dark-2016/prod22617...  Estados Unidos  tinto
# 134  wine.com.br/vinhos/perez-cruz-single-vineyard-...           Chile  tinto
# 198  wine.com.br/vinhos/perez-cruz-winemakers-selec...           Chile  tinto
# 215  wine.com.br/vinhos/maison-bouachon-les-rabassi...          França  tinto
# 245  wine.com.br/vinhos/carnivor-cabernet-sauvignon...  Estados Unidos  tinto
#
#                                            description  evaluation  \
# 21   Médio corpo, taninos presentes, boa acidez, fr...         4.0
# 97            Corpo médio, taninos gentis e boa acidez         3.5
# 124  Corpo de médio para encorpado, acidez agradáve...         4.5
# 134  Corpo de médio para encorpado, taninos present...         4.0
# 198  Médio corpo, taninos macios, acidez agradável,...         4.5
# 215  Frutado, bom corpo, taninos macios, acidez agr...         4.0
# 245  Corpo de médio para encorpado, taninos present...         4.5
#
#      rating_count  lowest_price  full_price  discount  \
# 21           17.0        123.41      147.90  0.165585
# 97            2.0         70.47       90.90  0.224752
# 124          29.0        108.12      141.90  0.238055
# 134          51.0         99.90       99.90  0.000000
# 198          42.0         99.90       99.90  0.000000
# 215          76.0         94.00      122.90  0.235151
# 245          34.0        117.53      117.53  0.000000
#
#                                            vivino_name  \
# 21            Tabali Witral Limited Edition Syrah 2016
# 97              Bodega Finca Las Moras Dadá Art 3 2018
# 124                      Apothic Dark (Red Blend) 2016
# 134   Perez Cruz La Higuera Block Single Vineyard 2017
# 198              Perez Cruz Winemaker's Selection 2017
# 215  Maison Bouachon Les Rabassieres Vieilles Vigne...
# 245                   Carnivor Cabernet Sauvignon 2016
#
#                         vivino_link  vivino_score  vivino_rating  vivino_price
# 21   www.vivino.com/wines/158443431           3.8          579.0           NaN
# 97   www.vivino.com/wines/156618798           3.8          672.0           NaN
# 124   www.vivino.com/wines/86701622           3.8         2944.0           NaN
# 134  www.vivino.com/wines/156052147           3.9          429.0           NaN
# 198  www.vivino.com/wines/152443541           3.9          300.0           NaN
# 215  www.vivino.com/wines/155157786           3.8          341.0           NaN
# 245   www.vivino.com/wines/87380454           3.8         8901.0         109.9

# %%
best_deals.describe()
# Out:
#        evaluation  rating_count  lowest_price  full_price  discount  \
# count    7.000000      7.000000      7.000000    7.000000  7.000000
# mean     4.142857     35.857143    101.904286  117.275714  0.123363
# std      0.377964     23.912539     17.339359   21.891432  0.117876
# min      3.500000      2.000000     70.470000   90.900000  0.000000
# 25%      4.000000     23.000000     96.950000   99.900000  0.000000
# 50%      4.000000     34.000000     99.900000  117.530000  0.165585
# 75%      4.500000     46.500000    112.825000  132.400000  0.229952
# max      4.500000     76.000000    123.410000  147.900000  0.238055
#
#        vivino_score  vivino_rating  vivino_price
# count      7.000000       7.000000           1.0
# mean       3.828571    2023.714286         109.9
# std        0.048795    3172.910006           NaN
# min        3.800000     300.000000         109.9
# 25%        3.800000     385.000000         109.9
# 50%        3.800000     579.000000         109.9
# 75%        3.850000    1808.000000         109.9
# max        3.900000    8901.000000         109.9

# %%
result.loc[result.lowest_price <= result.vivino_price]
# Out:
#                                       wine_name  \
# 93                    Norton Reserva Syrah 2014
# 216     Viña Oria D.O.P. Cariñena Garnacha 2018
# 218  Viña Labrada D.O.P. Cariñena Garnacha 2018
#
#                                                   link    country   type  \
# 93   wine.com.br/vinhos/norton-reserva-syrah-2014/p...  Argentina  tinto
# 216  wine.com.br/vinhos/vina-oria-d-o-p-carinena-ga...    Espanha  tinto
# 218  wine.com.br/vinhos/vina-labrada-d-o-p-carinena...    Espanha  tinto
#
#                                            description  evaluation  \
# 93    Na boca é aveludado e denso, com taninos deli...         0.0
# 216                        Jovem, boa acidez e frutado         3.5
# 218                       Frutado, jovem e equilibrado         4.0
#
#      rating_count  lowest_price  full_price  discount  \
# 93            0.0        135.18       159.9  0.154597
# 216           9.0         41.06        70.9  0.420874
# 218           8.0         41.06        70.9  0.420874
#
#                     vivino_name                     vivino_link  vivino_score  \
# 93    Norton Reserva Syrah 2014    www.vivino.com/wines/7285821           3.8
# 216     Viña Oria Garnacha 2018  www.vivino.com/wines/160064093           2.9
# 218  Viña Labrada Garnacha 2018  www.vivino.com/wines/160762029           3.4
#
#      vivino_rating  vivino_price
# 93           225.0         174.0
# 216           29.0          60.9
# 218           22.0          60.9

# %%
result.to_csv('result.csv',index=False)
best_deals.to_csv('best_deals',index=False)

# %%
import pandas as pd
import math
import matplotlib.pyplot as plt

work_df = pd.read_csv('result.csv')
work_df
# Out:
#                                              wine_name  \
# 0                      Chateau Oumsiyat Red Jaspe 2014
# 1        Protos Roble D.O. Ribeira Del Duero 1.5L 2017
# 2    Fantinel Borgo Tesis Doc Grave Cabernet Sauvig...
# 3                      Urmeneta Reserva Carménère 2018
# 4       Bridlewood Paso Robles Cabernet Sauvignon 2017
# 5        Frei Brothers Reserve Cabernet Sauvignon 2016
# 6                 Quinta de Pancas Grande Reserva 2015
# 17   www.vivino.com/wines/161680646           NaN            NaN           NaN
# 18    www.vivino.com/wines/98302557           3.6          348.0           NaN
# 19   www.vivino.com/wines/148524423           4.1           83.0           NaN
# 20   www.vivino.com/wines/158131602           3.4          163.0           NaN
# 21   www.vivino.com/wines/158443431           3.8          579.0           NaN
# 22     www.vivino.com/wines/7119470           3.4          469.0           NaN
# 23   www.vivino.com/wines/159086520           NaN            NaN           NaN
# 24   www.vivino.com/wines/154307103           3.7           76.0           NaN
# 25   www.vivino.com/wines/108868774           3.9          980.0           NaN
# 26     www.vivino.com/wines/3971465           3.8          894.0         340.0
# 27   www.vivino.com/wines/147821842           4.3          228.0           NaN
# 28   www.vivino.com/wines/148236144           3.5           78.0           NaN
# 29     www.vivino.com/wines/1483654           4.0          858.0           NaN
# ..                              ...           ...            ...           ...
# 234  www.vivino.com/wines/161933214           3.3           83.0           NaN
# 235  www.vivino.com/wines/154703581           3.6         1332.0           NaN
# 236  www.vivino.com/wines/145609415           3.3          282.0           NaN
# 237  www.vivino.com/wines/156485531           3.7          185.0           NaN
# 238  www.vivino.com/wines/160826350           NaN            NaN           NaN
# 239  www.vivino.com/wines/161972076           3.5          102.0           NaN
# 240  www.vivino.com/wines/161088545           3.3           82.0           NaN
# 241  www.vivino.com/wines/156854863           3.6           95.0           NaN
# 242  www.vivino.com/wines/157908925           3.6          277.0           NaN
# 243  www.vivino.com/wines/155636858           3.8           22.0           NaN
# 244  www.vivino.com/wines/156985814           3.9           41.0           NaN
# 245   www.vivino.com/wines/87380454           3.8         8901.0         109.9
# 246  www.vivino.com/wines/161695727           NaN            NaN           NaN
# 247   www.vivino.com/wines/96671737           3.7         1539.0          75.0
# 248  www.vivino.com/wines/156997659           3.3           39.0           NaN
# 249  www.vivino.com/wines/156250627           3.5          113.0          44.0
# 250  www.vivino.com/wines/156464792           3.5          360.0          46.9
# 251  www.vivino.com/wines/162640361           3.3          364.0           NaN
# 252  www.vivino.com/wines/152865070           3.5          113.0           NaN
# 253  www.vivino.com/wines/158973344           3.3           63.0           NaN
# 254  www.vivino.com/wines/158849334           3.5          235.0           NaN
# 255  www.vivino.com/wines/132030218           3.5           87.0         115.0
# 256  www.vivino.com/wines/157695445           4.0           95.0           NaN
# 257  www.vivino.com/wines/160893187           3.4           26.0           NaN
# 258  www.vivino.com/wines/152761412           3.6          193.0           NaN
# 259  www.vivino.com/wines/161942183           4.3           14.0           NaN
# 260  www.vivino.com/wines/153357405           3.8          243.0           NaN
# 261  www.vivino.com/wines/145586773           3.6           85.0           NaN
# 262  www.vivino.com/wines/160870634           3.6          632.0           NaN
# 263  www.vivino.com/wines/158848586           3.5          159.0           NaN
#
# [264 rows x 15 columns]

# %%
int(math.log10(work_df['lowest_price'].max()))
# Out:
# 4

# %%
### Referencia: wine_df.loc[(wine_df.evaluation > 3.1) & (wine_df.lowest_price < 200.0) & (wine_df.rating_count > 34.0)].boxplot(by='country',column=['lowest_price'], figsize=(15,10), patch_artist=True)

plot_df = work_df.loc[(work_df.lowest_price <= 400.0) & (work_df.vivino_rating >= work_df.vivino_rating.median())]
plot_df.boxplot(by='country',column=['lowest_price'], figsize=(17,10), patch_artist=True)

# %%
plot_df.boxplot(by='country',column=['vivino_score'], figsize=(17,10), patch_artist=True)

# %%
plot_df.boxplot(by='vivino_score',column=['lowest_price'], figsize=(17,10), patch_artist=True)

# %%
import numpy as np 
import seaborn as sns

fig, ax = plt.subplots(figsize=(10,10))
sns.stripplot(x="lowest_price", y="country", data=plot_df, ax=ax, jitter= True)
plt.show()

# %%
import numpy as np 
import seaborn as sns

fig, ax = plt.subplots(figsize=(17,10))
sns.swarmplot(x="vivino_score", y="country", data=plot_df, ax=ax)
plt.show()

# %%
import numpy as np 
import seaborn as sns

fig, ax = plt.subplots(figsize=(17,10))
sns.swarmplot(x="vivino_score", y="lowest_price", data=plot_df, ax=ax)
plt.show()

# %%
import numpy as np 
import seaborn as sns

fig, ax = plt.subplots(figsize=(17,10))
sns.swarmplot(x="evaluation", y="vivino_score", data=plot_df, ax=ax)
plt.show()

# %%
import numpy as np 
import seaborn as sns

fig, ax = plt.subplots(figsize=(17,10))
sns.swarmplot(x="country", y="vivino_rating", data=plot_df, ax=ax)
plt.show()

# %%
import numpy as np 
import seaborn as sns

fig, ax = plt.subplots(figsize=(17,10))
sns.swarmplot(x="lowest_price", y="vivino_rating", data=plot_df, ax=ax)
plt.show()

# %%
import numpy as np 
import seaborn as sns

fig, ax = plt.subplots(figsize=(17,10))
sns.swarmplot(x="vivino_score", y="vivino_rating", data=plot_df, ax=ax)
plt.show()

# %%
menor_preco = work_df.groupby(['country','vivino_score']).apply(lambda df: df.loc[df.lowest_price.idxmin()])
display(menor_preco)
# Out:
#                                                                     wine_name  \
# country       vivino_score
# Alemanha      3.6           Ernst Loosen Winemakers Select Pfalz Edition P...
#               4.0                  Ernst Loosen Pfalz Edition Dornfelder 2018
# Argentina     3.3                   Perdigón Malbec / Cabernet Sauvignon 2018
#               3.4           Partridge Reserva Edición Limitada Cabernet Sa...
#               3.5                                Partridge Flying Malbec 2019
# ...                                                                       ...
# África do Sul 3.5                                       Tormentoso Syrah 2016
#               3.6                   Fleur du Cap Essence du Cap Pinotage 2016
#               3.7                  Lievland Vineyards Bush Vine Pinotage 2017
#               4.0                                   Fleur Du Cap Laszlo 2015.
#               4.2                                       Marianne Floreal 2015
#
#                                                                          link  \
# country       vivino_score
# Alemanha      3.6           wine.com.br/vinhos/ernst-loosen-winemakers-sel...
#               4.0           wine.com.br/vinhos/ernst-loosen-pfalz-edition-...
# Argentina     3.3           wine.com.br/vinhos/perdigon-malbec-cabernet-sa...
#               3.4           wine.com.br/vinhos/partridge-reserva-edicion-l...
#               3.5           wine.com.br/vinhos/partridge-flying-malbec-201...
# ...                                                                       ...
# África do Sul 3.5           wine.com.br/vinhos/tormentoso-syrah-2016/prod2...
#               3.6           wine.com.br/vinhos/fleur-du-cap-essence-du-cap...
#               3.7           wine.com.br/vinhos/lievland-vineyards-bush-vin...
#               4.0           wine.com.br/vinhos/fleur-du-cap-laszlo-2015-/p...
#               4.2           wine.com.br/vinhos/marianne-floreal-2015/prod1...
#
#                                   country   type  \
# country       vivino_score
# Alemanha      3.6                Alemanha  tinto
#               4.0                Alemanha  tinto
# Argentina     3.3               Argentina  tinto
#               3.4               Argentina  tinto
#               3.5               Argentina  tinto
# ...                                   ...    ...
# África do Sul 3.5           África do Sul  tinto
#               3.6           África do Sul  tinto
#               3.7           África do Sul  tinto
#               4.0           África do Sul  tinto
#               4.2           África do Sul  tinto
#
#                                                                   description  \
# country       vivino_score
# Alemanha      3.6                      Leve, acidez presente, taninos sedosos
#               4.0             Frutado, leve, acidez agradável, taninos macios
# Argentina     3.3                      Taninos sedosos, boa acidez, saboroso.
#               3.4           Médio corpo, boa acidez, taninos macios, cacau...
#               3.5           Corpo de leve para médio, frutado, acidez agra...
# ...                                                                       ...
# África do Sul 3.5           Médio corpo, taninos macios, boa acidez, média...
#               3.6           Frutado, corpo de médio para encorpado, tanino...
#               3.7            Frutado, médio corpo, taninos macios, boa acidez
#               4.0           Complexo, intenso, encorpado, acidez agradável...
#               4.2           Harmônico, estruturado, acidez agradável, tani...
#
#                             evaluation  rating_count  lowest_price  \
# country       vivino_score
# Alemanha      3.6                  4.0          24.0         96.35
#               4.0                  4.5          10.0         88.12
# Argentina     3.3                  4.0          35.0         46.94
#               3.4                  4.0          82.0         70.47
#               3.5                  4.5          74.0         51.65
# ...                                ...           ...           ...
# África do Sul 3.5                  3.5          49.0         88.12
#               3.6                  4.0          27.0         75.18
#               3.7                  4.0          85.0         97.53
#               4.0                  0.0           0.0        705.76
#               4.2                  5.0           5.0        481.06
#
#                             full_price  discount  \
# country       vivino_score
# Alemanha      3.6                119.9  0.196414
#               4.0                117.9  0.252587
# Argentina     3.3                 49.9  0.059319
#               3.4                 79.9  0.118023
#               3.5                 59.9  0.137730
# ...                                ...       ...
# África do Sul 3.5                122.9  0.282994
#               3.6                117.9  0.362341
#               3.7                135.9  0.282340
#               4.0                798.9  0.116585
#               4.2                519.9  0.074707
#
#                                                                   vivino_name  \
# country       vivino_score
# Alemanha      3.6             Ernst Loosen Winemaker's Select Pinot Noir 2017
#               4.0                                Ernst Loosen Dornfelder 2018
# Argentina     3.3           Las Perdices Perdigón Malbec - Cabernet Sauvig...
#               3.4           Las Perdices Partridge Reserva Edición Limitad...
#               3.5                   Las Perdices Partridge Flying Malbec 2019
# ...                                                                       ...
# África do Sul 3.5                                       Tormentoso Syrah 2016
#               3.6                   Fleur du Cap Essence du Cap Pinotage 2016
#               3.7                   Lievland Vineyards Bushvine Pinotage 2017
#               4.0                                         Fleur du Cap Laszlo
#               4.2                                       Marianne Floreal 2015
#
#                                                vivino_link  vivino_score  \
# country       vivino_score
# Alemanha      3.6           www.vivino.com/wines/157879073           3.6
#               4.0           www.vivino.com/wines/160937862           4.0
# Argentina     3.3           www.vivino.com/wines/161933214           3.3
#               3.4           www.vivino.com/wines/158914649           3.4
#               3.5           www.vivino.com/wines/161972076           3.5
# ...                                                    ...           ...
# África do Sul 3.5           www.vivino.com/wines/158476133           3.5
#               3.6           www.vivino.com/wines/157908925           3.6
#               3.7           www.vivino.com/wines/158285939           3.7
#               4.0             www.vivino.com/wines/1483654           4.0
#               4.2           www.vivino.com/wines/148051404           4.2
#
#                             vivino_rating  vivino_price
# country       vivino_score
# Alemanha      3.6                   260.0           NaN
#               4.0                    10.0           NaN
# Argentina     3.3                    83.0           NaN
#               3.4                    60.0           NaN
#               3.5                   102.0           NaN
# ...                                   ...           ...
# África do Sul 3.5                  1149.0           NaN
#               3.6                   277.0           NaN
#               3.7                  2493.0           NaN
#               4.0                   858.0           NaN
#               4.2                    75.0           NaN
#
# [87 rows x 15 columns]

# %%
df = work_df.groupby(['country']).lowest_price.describe()

df[['count','mean','min','50%','max']]
# Out:
#                 count         mean     min      50%       max
# country
# Alemanha          2.0    92.235000   88.12   92.235     96.35
# Argentina        26.0   138.206923   46.94  101.060    451.65
# Austrália         2.0    94.000000   94.00   94.000     94.00
# Chile            38.0   184.585263   48.90   93.410   1058.71
# Espanha          42.0   121.894762   41.06   86.355    777.53
# Estados Unidos   23.0   850.327826   90.47  188.120   8938.71
# França           69.0  1861.073188   52.82  264.590  15870.47
# Itália           24.0   256.990000   52.82  168.115    941.06
# Líbano            2.0   161.060000  161.06  161.060    161.06
# Portugal         22.0   243.364545   58.71  124.645   1225.76
# Uruguai           1.0   225.760000  225.76  225.760    225.76
# África do Sul    12.0   217.040833   64.59   95.180    705.76
# Áustria           1.0   110.470000  110.47  110.470    110.47

# %%
resumo_df = work_df[['lowest_price','vivino_score']].describe()
resumo_df = resumo_df.style.format({'lowest_price': "{:.2}"})
resumo_df
# Out:
# <style  type="text/css" >
# </style><table id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >lowest_price</th>        <th class="col_heading level0 col1" >vivino_score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678clevel0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow0_col0" class="data row0 col0" >2.6e+02</td>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow0_col1" class="data row0 col1" >228.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678clevel0_row1" class="row_heading level0 row1" >mean</th>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow1_col0" class="data row1 col0" >6.8e+02</td>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow1_col1" class="data row1 col1" >3.756579</td>
#             </tr>
#             <tr>
#                         <th id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678clevel0_row2" class="row_heading level0 row2" >std</th>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow2_col0" class="data row2 col0" >1.9e+03</td>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow2_col1" class="data row2 col1" >0.329197</td>
#             </tr>
#             <tr>
#                         <th id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678clevel0_row3" class="row_heading level0 row3" >min</th>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow3_col0" class="data row3 col0" >4.1e+01</td>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow3_col1" class="data row3 col1" >2.900000</td>
#             </tr>
#             <tr>
#                         <th id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678clevel0_row4" class="row_heading level0 row4" >25%</th>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow4_col0" class="data row4 col0" >8.2e+01</td>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow4_col1" class="data row4 col1" >3.500000</td>
#             </tr>
#             <tr>
#                         <th id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678clevel0_row5" class="row_heading level0 row5" >50%</th>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow5_col0" class="data row5 col0" >1.2e+02</td>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow5_col1" class="data row5 col1" >3.700000</td>
#             </tr>
#             <tr>
#                         <th id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678clevel0_row6" class="row_heading level0 row6" >75%</th>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow6_col0" class="data row6 col0" >2.9e+02</td>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow6_col1" class="data row6 col1" >4.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678clevel0_row7" class="row_heading level0 row7" >max</th>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow7_col0" class="data row7 col0" >1.6e+04</td>
#                         <td id="T_9b79e3b4_a759_11ea_910e_b5b2b8bd678crow7_col1" class="data row7 col1" >4.600000</td>
#             </tr>
#     </tbody></table>

# %%
marker_size = pd.qcut(work_df.vivino_rating, q=[0, .25, .5, .75, 1.] , labels= [6, 12, 18, 24])
marker_size
# Out:
# 0       6.0
# 1       NaN
# 2       6.0
# 3       6.0
# 4      12.0
# 5      12.0
# 6      12.0
# 7      24.0
# 8       NaN
# 9      12.0
# 10     12.0
# 11      6.0
# 12     12.0
# 13      NaN
# 14     24.0
# 15     12.0
# 16      6.0
# 17      NaN
# 18     18.0
# 19      6.0
# 20     12.0
# 21     18.0
# 22     18.0
# 23      NaN
# 24      6.0
# 25     24.0
# 26     24.0
# 27     12.0
# 28      6.0
# 29     24.0
#        ...
# 234     6.0
# 235    24.0
# 236    12.0
# 237    12.0
# 238     NaN
# 239    12.0
# 240     6.0
# 241     6.0
# 242    12.0
# 243     6.0
# 244     6.0
# 245    24.0
# 246     NaN
# 247    24.0
# 248     6.0
# 249    12.0
# 250    18.0
# 251    18.0
# 252    12.0
# 253     6.0
# 254    12.0
# 255     6.0
# 256     6.0
# 257     6.0
# 258    12.0
# 259     6.0
# 260    12.0
# 261     6.0
# 262    18.0
# 263    12.0
# Name: vivino_rating, Length: 264, dtype: category
# Categories (4, int64): [6 < 12 < 18 < 24]
