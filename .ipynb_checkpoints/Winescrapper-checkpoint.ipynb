# %%
import requests
page = requests.get("https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-p1.html")
page
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup as bs

soup = bs(page.content, 'html.parser')

#branch = soup.find_all(class_='ProductList-content')
#branch = soup.select("div.ProductList-content li")
#item = branch[0].find('li')
#js = item.find('script')

# %%
product = soup.find('article', class_='ProductDisplay')

ProductName = product.find('div', class_='ProductDisplay-name')
product_name_a = ProductName.find('a')

print(product_name_a['title'])
print("https://wine.com.br" + product_name_a['href'])

country = product.find(class_="Country")
print(country.span.text)

wine_type = product.find(class_="ProductDisplay-type")
print(wine_type.span.text)

wine_description = product.find(class_="ProductDisplay-descriptionText")
print(wine_description.text)
      
# print(product_name_a.prettify())
# Out:
# Pérez Cruz Limited Edition D.O. Valle del Maipo Cabernet Franc 2016
# https://wine.com.br/vinhos/perez-cruz-limited-edition-d-o-valle-del-maipo-cabernet-franc-2016/prod20081.html
# Chile
# tinto
# Frutado, taninos presentes, médio corpo, fresco, amadeirado, especiarias

# %%
# Buscando Notas e numero de avaliações
import re

wine_rating = product.find('div',class_='Rating')
wine_evaluation_tag = wine_rating.find('evaluation-tag')
if (wine_evaluation_tag):
    wine_evaluation = re.compile(r"\d.\d").search(wine_evaluation_tag.prettify()).group()
    wine_rating_count = re.search(r"\d+", wine_rating.find(class_='Rating-count').text).group()
else:
    wine_evaluation = None
    wine_rating_count = 0

print(str(wine_rating))
print(wine_evaluation)
print(wine_rating_count)
# Out:
# <div class="Rating">
# <div class="Rating-stars">
# <div class="vue-evaluation-tag">
# <evaluation-tag :evaluation="4.0"></evaluation-tag>
# </div>
# </div>
# <a class="Rating-count" href="/vinhos/perez-cruz-limited-edition-d-o-valle-del-maipo-cabernet-franc-2016/prod20081.html#Comments">(7)</a>
# </div>
# 4.0
# 7

# %%
price_box = product.find(class_="ProductDisplay-priceBox")

lowest_price = price_box.find(class_="Price--lowestPrice").find(class_="Price-raw").text
full_price = price_box.find(class_="Price--fullPrice").find(class_="Price-raw").text
print(lowest_price)
print(full_price)

discount = 1-float(lowest_price)/float(full_price)
print(discount)
# Out:
# 145.76
# 180.90
# 0.1942509673852958

# %%
pages_list = soup.find('div', class_='Pagination').ul.find_all('li')
int(pages_list[len(pages_list)-1].a.text)
# Out:
# 44

# %%
wine_list = soup.find('div', class_='ProductList-content').ul.find_all('li')

for wine_item in wine_list:
    wine = wine_item.find('article', class_='ProductDisplay')

    wine_name = wine.find('div', class_='ProductDisplay-name').a['title']
    wine_link = "https://wine.com.br" + wine.find('div', class_='ProductDisplay-name').a['href']
    wine_country = wine.find(class_="Country").span.text
    wine_type = wine.find(class_="ProductDisplay-type").span.text
    wine_description = wine.find(class_="ProductDisplay-descriptionText").text
    
    wine_rating = wine.find('div',class_='Rating')
    wine_evaluation_tag = wine_rating.find('evaluation-tag')
    if (wine_evaluation_tag):
        wine_evaluation = re.compile(r"\d.\d").search(wine_evaluation_tag.prettify()).group()
        wine_rating_count = re.search(r"\d+", wine_rating.find(class_='Rating-count').text).group()
    else:
        wine_evaluation = None
        wine_rating_count = 0
    
    price_box = wine.find(class_="ProductDisplay-priceBox")

    lowest_price = price_box.find(class_="Price--lowestPrice").find(class_="Price-raw").text
    full_price = price_box.find(class_="Price--fullPrice").find(class_="Price-raw").text
    discount = 1-float(lowest_price)/float(full_price)
    
    
    print(wine_name,";", wine_evaluation, ";", wine_rating_count, ";", wine_country, ";", wine_type, ";", lowest_price, ";", full_price, ";", discount,";", wine_description, ";", wine_link)
# Out:
# Pérez Cruz Limited Edition D.O. Valle del Maipo Cabernet Franc 2016 ; 4.0 ; 7 ; Chile ; tinto ; 145.76 ; 180.90 ; 0.1942509673852958 ; Frutado, taninos presentes, médio corpo, fresco, amadeirado, especiarias ; https://wine.com.br/vinhos/perez-cruz-limited-edition-d-o-valle-del-maipo-cabernet-franc-2016/prod20081.html
# Finca La Chamiza Martín Alsina Malbec 2014 ; None ; 0 ; Argentina ; tinto ; 292.82 ; 495.90 ; 0.4095180479935471 ; Frutado, amadeirado, corpo de médio para encorpado, taninos presentes, acidez agradável ; https://wine.com.br/vinhos/finca-la-chamiza-martin-alsina-malbec-2014/prod20028.html
# Domaine L'Ostal Cazes Grand Vin 2015 ; None ; 0 ; França ; tinto ; 258.71 ; 335.90 ; 0.22980053587377192 ; Encorpado, boa acidez, taninos macios ; https://wine.com.br/vinhos/domaine-l-ostal-cazes-grand-vin-2015/prod20143.html
# Maycas del Limarí Reserva Especial Pinot Noir 2017 ; 4.5 ; 23 ; Chile ; tinto ; 166.94 ; 206.90 ; 0.19313678105364918 ; Bom corpo, acidez presente, taninos sedosos, frutado ; https://wine.com.br/vinhos/maycas-del-limari-reserva-especial-pinot-noir-2017/prod20221.html
# Pauillac De Lynch-Bages 2015 ; 3.0 ; 1 ; França ; tinto ; 364.59 ; 630.90 ; 0.4221112696148359 ; Médio corpo, boa acidez, taninos presentes, final longo ; https://wine.com.br/vinhos/pauillac-de-lynch-bages-2015/prod20236.html
# Château Puy-Blanquet A.O.C. Saint-Émilion Grand Cru 2011 ; 3.5 ; 2 ; França ; tinto ; 359.88 ; 445.90 ; 0.19291320923973987 ; Elegante, acidez agradável, bom corpo, taninos macios ; https://wine.com.br/vinhos/chateau-puy-blanquet-a-o-c-saint-emilion-grand-cru-2011/prod20203.html
# Jean-Pierre Moueix A.O.C. Pomerol 2015 ; None ; 0 ; França ; tinto ; 339.88 ; 414.90 ; 0.18081465413352615 ; Médio corpo, taninos macios, acidez agradável, final longo ; https://wine.com.br/vinhos/jean-pierre-moueix-a-o-c-pomerol-2015/prod20199.html
# Echo de Lynch-Bages A.O.C. Pauillac 2014 ; None ; 0 ; França ; tinto ; 721.06 ; 1056.90 ; 0.3177594852871607 ; Exuberante, encorpado, taninos presentes, boa acidez, final longo ; https://wine.com.br/vinhos/echo-de-lynch-bages-a-o-c-pauillac-2014/prod20208.html
# Château La Fleur-Pétrus A.O.C. Pomerol 2006 ; None ; 0 ; França ; tinto ; 3614.00 ; 6036.90 ; 0.40134837416554847 ; Aveludado, complexo, boa acidez, corpo de médio para encorpado ; https://wine.com.br/vinhos/chateau-la-fleur-petrus-a-o-c-pomerol-2006/prod20202.html

# %%
from bs4 import BeautifulSoup as bs
import pandas as pd
import requests
import re
import time

URL_RAIZ="https://www.wine.com.br"
URL_BASE = URL_RAIZ+"/vinhos/tinto/cVINHOS-atTIPO_TINTO-p{0}.html"


HEADERS = {
    'user-agent': ('Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 '
                   '(KHTML, like Gecko) Chrome/78.0.3904.87 Safari/537.36')
}

# %%
def get_num_pages(soup):
    
    pages_list = soup.find('div', class_='Pagination').ul.find_all('li')
    num_pages = int(pages_list[len(pages_list)-1].a.text) + 1
    
    return num_pages

def scrape_soup(soup):
    
    list_name=[]
    list_link, list_country, list_type, list_description= [], [], [], []
    list_evaluation, list_rating_count= [], []
    list_lowest_price, list_full_price, list_discount= [], [], []
    
    wine_list = soup.find('div', class_='ProductList-content').ul.find_all('li')

    for wine_item in wine_list:
        
        try:
            wine = wine_item.find('article', class_='ProductDisplay')

            wine_name = wine.find('div', class_='ProductDisplay-name').a['title']
            wine_link = "https://wine.com.br" + wine.find('div', class_='ProductDisplay-name').a['href']
            wine_country = wine.find(class_="Country").span.text
            wine_type = wine.find(class_="ProductDisplay-type").span.text
            wine_description = wine.find(class_="ProductDisplay-descriptionText").text
        
            wine_rating = wine.find('div',class_='Rating')
            wine_evaluation_tag = wine_rating.find('evaluation-tag')
            if (wine_evaluation_tag):
                wine_evaluation = float(re.compile(r"\d.\d").search(wine_evaluation_tag.prettify()).group())
                wine_rating_count = float(re.search(r"\d+", wine_rating.find(class_='Rating-count').text).group())
            else:
                wine_evaluation = 0
                wine_rating_count = 0
    
        
            price_box = wine.find(class_="ProductDisplay-priceBox")

            lowest_price = float(price_box.find(class_="Price--lowestPrice").find(class_="Price-raw").text)
            full_price = float(price_box.find(class_="Price--fullPrice").find(class_="Price-raw").text)
            discount = 1-float(lowest_price)/float(full_price)
        except:
            print('skip incomplete item')
            continue
        
        list_name.append(wine_name)
        list_link.append(wine_link)
        list_country.append(wine_country)
        list_type.append(wine_type)
        list_description.append(wine_description)
        
        list_evaluation.append(wine_evaluation)
        list_rating_count.append(wine_rating_count)

        list_lowest_price.append(lowest_price)
        list_full_price.append(full_price)
        list_discount.append(discount)
        
        ###print(wine_name,";", wine_evaluation, ";", wine_rating_count, ";", wine_country, ";", wine_type, ";", lowest_price, ";", full_price, ";", discount,";", wine_link)
    
    df = pd.DataFrame({
        'wine_name': list_name,
        'link': list_link,
        'country': list_country,
        'type': list_type,
        'description': list_description,
        'evaluation': list_evaluation,
        'rating_count': list_rating_count,
        'lowest_price': list_lowest_price,
        'full_price': list_full_price,
        'discount': list_discount
    })
    
    return df
        
    

def get_soup(page_url, retry_count=0):
    
    session= requests.Session()
    
    try:
        response = session.get(page_url, headers=HEADERS)
    except:
        retry_count += 1
        if retry_count <= 3:
            session = requests.Session()
            get_soup(page_url, retry_count)
        else:
            raise
            
    print("\nScraping page:",page_url," = ", response)
    
    soup = bs(response.content, 'html.parser')
    
    return soup

# %%
pages_to_scrape = 4

current_page = 1

wine_df = pd.DataFrame(columns=['wine_name','link','country','type','description','evaluation','rating_count','lowest_price','full_price','discount'])

while (current_page != pages_to_scrape):
    
    wine_soup = get_soup(URL_BASE.format(current_page))
    
    if current_page == 1:
        pages_to_scrape = get_num_pages(wine_soup)
    
    new_df = scrape_soup(wine_soup)
    wine_df= wine_df.append(new_df, ignore_index=True)
    
    ###print(current_page)
    
    time.sleep(10)
    current_page += 1
    
print("Scrape finished.")
wine_df
# Out:
# Scraping page: https://www.wine.com.br/vinhos/tinto/cVINHOS-atTIPO_TINTO-
# 353   Na boca, tem boa entrada, é untuoso e bem con...         0.0
# 354  Na boca apresenta boa estrutura, maciez e fres...         0.0
# 355   Em boca é fresco, frutado e com final de boca...         0.0
# 356   Final persistente com notas de chocolate amargo.         0.0
# 357  O paladar revela sabores de framboesas com cob...         0.0
#
#     rating_count  lowest_price  full_price  discount
# 0              7        145.76      180.90  0.194251
# 1              0        292.82      495.90  0.409518
# 2              0        258.71      335.90  0.229801
# 3             23        166.94      206.90  0.193137
# 4              1        364.59      630.90  0.422111
# 5              2        359.88      445.90  0.192913
# 6              0        339.88      414.90  0.180815
# 7              0        721.06     1056.90  0.317759
# 8              0       3614.00     6036.90  0.401348
# 9              9        179.88      222.90  0.193001
# 10            10         84.59      167.90  0.496188
# 11            21        104.59      157.90  0.337619
# 12             1        705.76      982.90  0.281962
# 13             0       2059.88     3041.90  0.322831
# 14             5        151.65      168.90  0.102131
# 15             2        136.90      136.90  0.000000
# 16            19        118.71      174.90  0.321269
# 17            18         88.12      174.90  0.496169
# 18             2        322.24      490.90  0.343573
# 19             2        215.18      298.90  0.280094
# 20             6        154.00      229.90  0.330144
# 21             1        372.82      456.90  0.184023
# 22            10       1066.94     1370.90  0.221723
# 23             6        325.76      588.90  0.446833
# 24             3        186.90      186.90  0.000000
# 25             6        156.35      193.90  0.193657
# 26             1        268.12      332.90  0.194593
# 27             0        337.53      589.90  0.427818
# 28             9        114.00      139.90  0.185132
# 29             1        271.65      435.90  0.376807
# ..           ...           ...         ...       ...
# 328           99        132.90      132.90  0.000000
# 329          324        130.47      179.90  0.274764
# 330           20        114.90      114.90  0.000000
# 331          489         41.06       52.90  0.223819
# 332           32         62.90       62.90  0.000000
# 333           16         39.88       48.90  0.184458
# 334            8         37.53       68.90  0.455298
# 335          486         58.90       58.90  0.000000
# 336           28        118.34      118.34  0.000000
# 337           21         70.47      117.90  0.402290
# 338           75         39.88       43.90  0.091572
# 339           19         52.82      109.90  0.519381
# 340            0        365.76      453.90  0.194184
# 341            1         36.35       45.90  0.208061
# 342            3        414.90      414.90  0.000000
# 343           22         37.53       46.90  0.199787
# 344          142         39.88       53.90  0.260111
# 345           17        235.17      261.90  0.102062
# 346          426         64.90       64.90  0.000000
# 347           23         90.47      112.90  0.198671
# 348            2        634.00      830.90  0.236972
# 349            0        135.18      159.90  0.154597
# 350            0         82.24       98.90  0.168453
# 351            0         88.12       98.90  0.108999
# 352            0        211.65      249.90  0.153061
# 353            0        282.24      329.90  0.144468
# 354            0        117.53      139.90  0.159900
# 355            0         82.24       98.90  0.168453
# 356            0        152.82      179.90  0.150528
# 357            0        152.82      179.90  0.150528
#
# [358 rows x 10 columns]

# %%
wine_df.loc[wine_df['rating_count']>=100]
wine_df.loc[189,'link']
# Out:
# 'https://wine.com.br/vinhos/bear-flag-red-blend-2018/prod23266.html'

# %%
wine_deals = wine_df.loc[(wine_df.rating_count>=36) & (wine_df.evaluation >= 4.2) & (wine_df.lowest_price < 66.20)]
wine_deals
# Out:
#                                              wine_name  \
# 160        Esteban Martín Reserva D.O.P. Cariñena 2014
# 230                 V9 Reserva Cabernet Sauvignon 2018
# 272   Gérard Bertrand Narbo Martius Réserve Blend 2018
# 298        Esteban Martín D.O.P. Cariñena Crianza 2015
# 323                  Root: 1 Reserva Heritage Red 2018
# 331  Toro Loco D.O.P. Utiel-Requena Tinto Superior ...
# 346  Gérard Bertrand Narbo Martius Cabernet Sauvign...
#
#                                                   link  country   type  \
# 160  https://wine.com.br/vinhos/esteban-martin-rese...  Espanha  tinto
# 230  https://wine.com.br/vinhos/v9-reserva-cabernet...    Chile  tinto
# 272  https://wine.com.br/vinhos/gerard-bertrand-nar...   França  tinto
# 298  https://wine.com.br/vinhos/esteban-martin-d-o-...  Espanha  tinto
# 323  https://wine.com.br/vinhos/root-1-reserva-heri...    Chile  tinto
# 331  https://wine.com.br/vinhos/toro-loco-d-o-p-uti...  Espanha  tinto
# 346  https://wine.com.br/vinhos/gerard-bertrand-nar...   França  tinto
#
#                                            description  evaluation  \
# 160  Médio corpo, taninos macios, boa acidez, final...         4.5
# 230      Frutado, bom corpo, taninos presentes, fresco         4.5
# 272     Elegante, taninos aveludados e final agradável         4.5
# 298      Médio corpo, acidez agradável, taninos firmes         4.5
# 323      Médio corpo, taninos macios, acidez agradável         4.5
# 331  Frutado, corpo de leve para médio, taninos mac...         4.5
# 346              Encorpado, taninos finos, final longo         4.5
#
#     rating_count  lowest_price  full_price  discount
# 160           94         65.76       88.90  0.260292
# 230           59         50.47       62.90  0.197615
# 272          407         54.67       54.67  0.000000
# 298           63         55.18       73.90  0.253315
# 323           90         56.35       69.90  0.193848
# 331          489         41.06       52.90  0.223819
# 346          426         64.90       64.90  0.000000

# %%
wine_exotic = wine_df.loc[~wine_df.country.isin(['Chile','França','Espanha','Argentina','Itália','Portugal','Brasil','Estados Unidos','Uruguai'])]
wine_exotic.loc[wine_exotic.country == 'China']

#wine_exotic.iloc[2].link
# Out:
#                                     wine_name  \
# 103     Changyu Reserve Noble Dragon Red 2016
# 295  Chateau Moser XV Cabernet Sauvignon 2017
#
#                                                   link country   type  \
# 103  https://wine.com.br/vinhos/changyu-reserve-nob...   China  tinto
# 295  https://wine.com.br/vinhos/chateau-moser-xv-ca...   China  tinto
#
#                              description  evaluation rating_count  \
# 103  Encorpado, frutado, taninos firmes.         3.5           81
# 295      Saboroso, encorpado, boa acidez         3.5           21
#
#      lowest_price  full_price  discount
# 103         55.18        76.9  0.282445
# 295         46.94        85.9  0.453551

# %%
wine_df.lowest_price.describe()
# Out:
# count      358.000000
# mean       492.251061
# std       1559.608840
# min         36.350000
# 25%         66.160000
# 50%        105.175000
# 75%        209.077500
# max      14598.710000
# Name: lowest_price, dtype: float64

# %%
wine_df.loc[wine_df.evaluation > 0].describe()
# Out:
#        evaluation  lowest_price    full_price    discount
# count  281.000000    281.000000    281.000000  281.000000
# mean     4.019573    215.992776    310.587651    0.231851
# std      0.602502    755.912080   1198.043521    0.140507
# min      1.000000     36.350000     43.900000    0.000000
# 25%      4.000000     62.240000     83.900000    0.160072
# 50%      4.000000     88.120000    120.900000    0.236060
# 75%      4.500000    148.120000    189.900000    0.327500
# max      5.000000   9303.410000  14794.900000    0.542016

# %%
print(wine_df.country.describe())
print(wine_df.rating_count.mean())
print(wine_df.country.unique())
# Out:
# count        358
# unique        14
# top       França
# freq          75
# Name: country, dtype: object
# 35.05865921787709
# ['Chile' 'Argentina' 'França' 'Itália' 'Espanha' 'Estados Unidos'
#  'Portugal' 'Brasil' 'Uruguai' 'Áustria' 'Líbano' 'China' 'África do Sul'
#  'Austrália']

# %%
wine_df.groupby('country').lowest_price.min()
# Out:
# country
# Argentina          36.35
# Austrália          58.71
# Brasil             57.53
# Chile              37.53
# China              46.94
# Espanha            39.88
# Estados Unidos     52.82
# França             39.88
# Itália             39.88
# Líbano            125.76
# Portugal           37.53
# Uruguai            38.71
# África do Sul      45.76
# Áustria           126.94
# Name: lowest_price, dtype: float64

# %%
wine_deals.groupby('country').lowest_price.min()
# Out:
# country
# Chile      50.47
# Espanha    41.06
# França     54.67
# Name: lowest_price, dtype: float64

# %%
wine_df.groupby(['country','type']).apply(lambda df: df.loc[df.evaluation.idxmax()])
# Out:
#                                                               wine_name  \
# country        type
# Argentina      tinto           Salentein Killka Cabernet Sauvignon 2018
# Austrália      tinto                Oxford Landing Cabernet Shiraz 2016
# Brasil         tinto                                 Salton Desejo 2015
# Chile          tinto                                           VIK 2012
# China          tinto              Changyu Reserve Noble Dragon Red 2016
# Espanha        tinto                      Parlanchín D.O.Ca. Rioja 2017
# Estados Unidos tinto      Frei Brothers Reserve Cabernet Sauvignon 2016
# França         tinto                         Reclos de La Couronne 2014
# Itália         tinto  Val delle Rose Aurelio D.O.C. Maremma Toscana ...
# Líbano         tinto                    Chateau Oumsiyat Red Syrah 2015
# Portugal       tinto           Pinhal Da Torre Special D.O.C. Tejo 2008
# Uruguai        tinto          Viñedo de los Vientos Anarkia Tannat 2018
# África do Sul  tinto                              Marianne Floreal 2015
# Áustria        tinto                          Zweigelt Classic Red 2017
#
#                                                                    link  \
# country        type
# Argentina      tinto  https://wine.com.br/vinhos/salentein-killka-ca...
# Austrália      tinto  https://wine.com.br/vinhos/oxford-landing-cabe...
# Brasil         tinto  https://wine.com.br/vinhos/salton-desejo-2015/...
# Chile          tinto  https://wine.com.br/vinhos/vik-2012/prod21001....
# China          tinto  https://wine.com.br/vinhos/changyu-reserve-nob...
# Espanha        tinto  https://wine.com.br/vinhos/parlanchin-d-o-ca-r...
# Estados Unidos tinto  https://wine.com.br/vinhos/frei-brothers-reser...
# França         tinto  https://wine.com.br/vinhos/reclos-de-la-couron...
# Itália         tinto  https://wine.com.br/vinhos/val-delle-rose-aure...
# Líbano         tinto  https://wine.com.br/vinhos/chateau-oumsiyat-re...
sorted_wines = wine_deals.sort_values(by=['lowest_price','evaluation'])
sorted_wines
# Out:
#                                              wine_name  \
# 331  Toro Loco D.O.P. Utiel-Requena Tinto Superior ...
# 230                 V9 Reserva Cabernet Sauvignon 2018
# 272   Gérard Bertrand Narbo Martius Réserve Blend 2018
# 298        Esteban Martín D.O.P. Cariñena Crianza 2015
# 323                  Root: 1 Reserva Heritage Red 2018
# 346  Gérard Bertrand Narbo Martius Cabernet Sauvign...
# 160        Esteban Martín Reserva D.O.P. Cariñena 2014
#
#                                                   link  country   type  \
# 331  https://wine.com.br/vinhos/toro-loco-d-o-p-uti...  Espanha  tinto
# 230  https://wine.com.br/vinhos/v9-reserva-cabernet...    Chile  tinto
# 272  https://wine.com.br/vinhos/gerard-bertrand-nar...   França  tinto
# 298  https://wine.com.br/vinhos/esteban-martin-d-o-...  Espanha  tinto
# 323  https://wine.com.br/vinhos/root-1-reserva-heri...    Chile  tinto
# 346  https://wine.com.br/vinhos/gerard-bertrand-nar...   França  tinto
# 160  https://wine.com.br/vinhos/esteban-martin-rese...  Espanha  tinto
#
#                                            description  evaluation  \
# 331  Frutado, corpo de leve para médio, taninos mac...         4.5
# 230      Frutado, bom corpo, taninos presentes, fresco         4.5
# 272     Elegante, taninos aveludados e final agradável         4.5
# 298      Médio corpo, acidez agradável, taninos firmes         4.5
# 323      Médio corpo, taninos macios, acidez agradável         4.5
# 346              Encorpado, taninos finos, final longo         4.5
# 160  Médio corpo, taninos macios, boa acidez, final...         4.5
#
#     rating_count  lowest_price  full_price  discount
# 331          489         41.06       52.90  0.223819
# 230           59         50.47       62.90  0.197615
# 272          407         54.67       54.67  0.000000
# 298           63         55.18       73.90  0.253315
# 323           90         56.35       69.90  0.193848
# 346          426         64.90       64.90  0.000000
# 160           94         65.76       88.90  0.260292

# %%
for index, row in sorted_wines.iterrows():
    print(row.wine_name, "\t", row.link)
# Out:
# Toro Loco D.O.P. Utiel-Requena Tinto Superior 2018 	 https://wine.com.br/vinhos/toro-loco-d-o-p-utiel-requena-tinto-superior-2018/prod23299.html
# V9 Reserva Cabernet Sauvignon 2018 	 https://wine.com.br/vinhos/v9-reserva-cabernet-sauvignon-2018/prod22182.html
# Gérard Bertrand Narbo Martius Réserve Blend 2018 	 https://wine.com.br/vinhos/gerard-bertrand-narbo-martius-reserve-blend-2018/prod23409.html
# Esteban Martín D.O.P. Cariñena Crianza 2015 	 https://wine.com.br/vinhos/esteban-martin-d-o-p-carinena-crianza-2015/prod20149.html
# Root: 1 Reserva Heritage Red 2018 	 https://wine.com.br/vinhos/root-1-reserva-heritage-red-2018/prod22767.html
# Gérard Bertrand Narbo Martius Cabernet Sauvignon 2018 	 https://wine.com.br/vinhos/gerard-bertrand-narbo-martius-cabernet-sauvignon-2018/prod23408.html
# Esteban Martín Reserva D.O.P. Cariñena 2014 	 https://wine.com.br/vinhos/esteban-martin-reserva-d-o-p-carinena-2014/prod20150.html
