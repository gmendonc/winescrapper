# %% [markdown]
# Mongodb
#
# client = pymongo.MongoClient("mongodb+srv://winemaster:<password>@projectw-vkqlx.mongodb.net/test?retryWrites=true&w=majority")
# db = client.test

# %%
#Imports
import pandas as pd
from pymongo import MongoClient

#Load csv dataset
data = pd.read_csv('result.csv')

# Connect to Mongodb
client = MongoClient("mongodb+srv://winemaster:winescrape7@projectw-vkqlx.mongodb.net/test?retryWrites=true&w=majority")
db = client['winedb']
collection = db['wines']

data.reset_index(inplace=True)
data_dict = data.to_dict("records")

# Insert collection
collection.insert_many(data_dict)

# %%
#Imports
import pandas as pd
from pymongo import MongoClient

# Connect to Mongodb
client = MongoClient("mongodb+srv://winemaster:winescrape7@projectw-vkqlx.mongodb.net/test?retryWrites=true&w=majority")
db = client['winedb']
collection = db['wines']

df = pd.DataFrame(list(collection.find()))
del df['_id']
df
# Out:
#      index  Unnamed: 0                                          wine_name  \
# 0        0           0  Pérez Cruz Limited Edition D.O. Valle del Maip...
# 1        1           1         Finca La Chamiza Martín Alsina Malbec 2014
# 2        2           2               Domaine L'Ostal Cazes Grand Vin 2015
# 3        3           3  Maycas del Limarí Reserva Especial Pinot Noir ...
# 4        4           4                       Pauillac De Lynch-Bages 2015
# ..     ...         ...                                                ...
# 363    363         363  Antinori Santa Cristina I.G.T. Toscana Rosso 2017
# 364    364         364  Antinori Santa Cristina I.G.T. Toscana Rosso 2017
# 365    365         365  Antinori Santa Cristina I.G.T. Toscana Rosso 2017
# 366    366         366                 Villa Antinori I.G.T. Toscana 2016
# 367    367         367  Columbia Crest Grand Estates Cabernet Sauvigno...
#
#                                                   link         country   type  \
# 0    wine.com.br/vinhos/perez-cruz-limited-edition-...           Chile  tinto
# 1    wine.com.br/vinhos/finca-la-chamiza-martin-als...       Argentina  tinto
# 2    wine.com.br/vinhos/domaine-l-ostal-cazes-grand...          França  tinto
# 3    wine.com.br/vinhos/maycas-del-limari-reserva-e...           Chile  tinto
# 4    wine.com.br/vinhos/pauillac-de-lynch-bages-201...          França  tinto
# ..                                                 ...             ...    ...
# 363  wine.com.br/vinhos/antinori-santa-cristina-i-g...          Itália  tinto
# 364  wine.com.br/vinhos/antinori-santa-cristina-i-g...          Itália  tinto
# 365  wine.com.br/vinhos/antinori-santa-cristina-i-g...          Itália  tinto
# 366  wine.com.br/vinhos/villa-antinori-i-g-t-toscan...          Itália  tinto
# 367  wine.com.br/vinhos/columbia-crest-grand-estate...  Estados Unidos  tinto
#
#                                            description  evaluation  \
# 0    Frutado, taninos presentes, médio corpo, fresc...         4.0
# 1    Frutado, amadeirado, corpo de médio para encor...         0.0
# 2                Encorpado, boa acidez, taninos macios         0.0
# 3    Bom corpo, acidez presente, taninos sedosos, f...         4.5
# 4    Médio corpo, boa acidez, taninos presentes, fi...         3.0
# ..                                                 ...         ...
# 363  Na boca apresenta boa estrutura, maciez e fres...         0.0
# 364  Na boca apresenta boa estrutura, maciez e fres...         0.0
# 365  Na boca apresenta boa estrutura, maciez e fres...         0.0
# 366  Na boca apresenta bom corpo, taninos macios e ...         0.0
# 367   Final persistente com notas de chocolate amargo.         0.0
#
#      rating_count  lowest_price  full_price  discount  \
# 0             7.0        145.76       180.9  0.194251
# 1             0.0        292.82       495.9  0.409518
# 2             0.0        258.71       335.9  0.229801
# 3            23.0        166.94       206.9  0.193137
# 4             1.0        364.59       630.9  0.422111
# ..            ...           ...         ...       ...
# 363           0.0        117.53       139.9  0.159900
# 364           0.0        117.53       139.9  0.159900
# 365           0.0        117.53       139.9  0.159900
# 366           0.0        211.65       249.9  0.153061
# 367           0.0        152.82       179.9  0.150528
#
#                                            vivino_name  \
# 0       Perez Cruz Cabernet Franc Limited Edition 2016
# 1                 La Chamiza Martin Alsina Malbec 2014
# 2    L'Ostal Cazes Grand Vin Minervois La Livinière...
# 3    Maycas del Limari Reserva Especial Pinot Noir ...
# 4     Château Lynch-Bages Pauillac de Lynch-Bages 2015
# ..                                                 ...
# 363                Santa Cristina a Pancole Rosso 2017
# 364                Santa Cristina a Pancole Rosso 2017
# 365                Santa Cristina a Pancole Rosso 2017
# 366        Antinori Villa Antinori Toscana Bianco 2016
# 367  Columbia Crest Grand Estates Cabernet Sauvigno...
#
#                         vivino_link  vivino_score  vivino_rating  vivino_price
# 0    www.vivino.com/wines/144769511           4.0          881.0         129.5
# 1     www.vivino.com/wines/11537877           4.2           97.0         168.0
# 2    www.vivino.com/wines/120763131           3.9          219.0           NaN
# 3    www.vivino.com/wines/152575001           3.7          222.0           NaN
# 4     www.vivino.com/wines/63019180           4.0          382.0           NaN
# ..                              ...           ...            ...           ...
# 363  www.vivino.com/wines/161602898           NaN            NaN           NaN
# 364  www.vivino.com/wines/161602898           NaN            NaN           NaN
# 365  www.vivino.com/wines/161602898           NaN            NaN           NaN
# 366   www.vivino.com/wines/92086715           3.8         6591.0           NaN
# 367   www.vivino.com/wines/86472793           3.7         3388.0           NaN
#
# [368 rows x 17 columns]

# %%
#Imports
import pandas as pd
from pymongo import MongoClient

#Load csv dataset
data = pd.read_csv('result.csv')

# Connect to Mongodb
client = MongoClient("mongodb+srv://winemaster:winescrape7@projectw-vkqlx.mongodb.net/test?retryWrites=true&w=majority")
db = client['winedb']
collection = db['wines']

data.reset_index(inplace=True)
data_dict = data.to_dict("records")

# Insert collection
collection.insert_many(data_dict)
